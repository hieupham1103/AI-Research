# %% [markdown]
# Model nhận biết hành động đánh hay không đánh

# %%
import os
import kagglehub

# Download latest version
dataset_path = kagglehub.dataset_download("naveenk903/movies-fight-detection-dataset") + "/Peliculas"

print("Path to dataset files:", dataset_path)
# Out:
# Path to dataset files: /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas

# %%
labels = ['noFights', 'fights']
labels2id = {'noFights': 0, 'fights': 1}

print(labels)

number_of_labels = 2
# Out:
# ['noFights', 'fights']

# %%
import torch
from torch import nn
import torch.nn.functional as f
from PIL import Image
from torchvision import models, transforms, datasets
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

INPUTSIZE = 224

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


def load_video_to_tensors(video_path):
    # Open the video file
    video = cv2.VideoCapture(video_path)

    frames = []

    while True:
        ret, frame = video.read()
        if not ret:
            break

        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        frame = cv2.resize(frame, (INPUTSIZE, INPUTSIZE), interpolation=cv2.INTER_LINEAR)
        # plt.figure()
        # plt.imshow(frame)

        frame = torch.from_numpy(frame).float().permute(2,0,1)

        # print(frame.size())
        frames.append(frame)


    video.release()

    return frames

dataset = []

for label in labels:
    label_path = f"{dataset_path}/{label}"

    for video in os.listdir(label_path):
        video_path = f"{label_path}/{video}"
        print(video_path)
        x = load_video_to_tensors(video_path)
        y = torch.tensor(labels2id[label])
        # print(x, y)
        # break

        dataset.append((x,y))
# Out:
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/17.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/16.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/28.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/14.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/100.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/15.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/29.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/11.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/39.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/12 (1).mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/38.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/10.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/13.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/48.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/74.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/60.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/61.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/75.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/49.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/63.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/77.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/88.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/89.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/76.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/62.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/26 (1).mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/66.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/72.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/8.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/99.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/98.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/9.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/73.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/71avi.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/65.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/59.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/58.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/64.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/70.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/69.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/7.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/55.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/96.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/82.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/83.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/97.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/40.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/6.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/54.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/68.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/56.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/81.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/95.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/94.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/80.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/57.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/5.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/41 (1).mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/47.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/1.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/53.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/84.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/33 (1).mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/90.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/91.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/85.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/52.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/46.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/50.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/2.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/44.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/78.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/93.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/87.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/86.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/92.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/79.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/45.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/51.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/3.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/67 (1).mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/36.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/22.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/43 (1).mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/23.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/37.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/21.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/35.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/4 (1).mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/34.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/24.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/30.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/18.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/19.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/31.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/25.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/20 (1).mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/33.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/27.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/42 (1).mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/32.mpg
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi26.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi32.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi33.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi27.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi19.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi31.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi25.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi24.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi30.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi18.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi34.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi20.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi21.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi35.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi23.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi37.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi36.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi22.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi9.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi79.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi45.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi51.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi86.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi92.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi93.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi87.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi50.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi44.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi78.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi8.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi52.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi46.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi91.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi85.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi84.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi90.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi47.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi53.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi57.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi43.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi94.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi80.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi81.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi95.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi42.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi56.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi40.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi54.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi68.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi83.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi97.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi96.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi82.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi69.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi55.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi41.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi58.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi64.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi70.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi71.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi65.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi59.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi1.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi3.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi73.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi67.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi98.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi99.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi66.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi72.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi2.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi6.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi76.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi62.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi89.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi88.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi63.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi77.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi7.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi5.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi61.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi75.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi49.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi48.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi60.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi4.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi100.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi13.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi12.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi74avi.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi38.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi10.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi11.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi39.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi15.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi29.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi28.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi14.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi16.avi
# /Users/phamdinhtrunghieu/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi17.avi

# %%
import random

random.shuffle(dataset)

# %%
class GetFeature(nn.Module):
    def __init__(self):
        super().__init__()
        input_size  = INPUTSIZE

        self.conv1 = nn.Conv2d(3, 64, kernel_size = 3, stride = 1, padding = 1)
        self.maxpool1 = nn.MaxPool2d(2,2)
        input_size //= 2
        self.conv2 = nn.Conv2d(64, 128, kernel_size = 3, stride = 1, padding = 1)
        self.maxpool2 = nn.MaxPool2d(2,2)
        input_size //= 2
        self.conv3 = nn.Conv2d(128, 256, kernel_size = 3, stride = 1, padding = 1)
        self.maxpool3 = nn.MaxPool2d(2,2)
        input_size //= 2
        self.conv4 = nn.Conv2d(256, 512, kernel_size = 3, stride = 1, padding = 1)
        self.maxpool4 = nn.MaxPool2d(2,2)
        input_size //= 2

        self.fc1 = nn.Linear(input_size * input_size * 512, INPUTSIZE)

    def forward(self, x):

        x = f.relu(self.conv1(x))
        x = self.maxpool1(x)
        x = f.relu(self.conv2(x))
        x = self.maxpool2(x)
        x = f.relu(self.conv3(x))
        x = self.maxpool3(x)
        x = f.relu(self.conv4(x))
        x = self.maxpool4(x)

        x = torch.flatten(x)

        x = f.tanh(self.fc1(x))

        return x

# %% [markdown]
# # RNN

# %%
class RNNCell(nn.Module):
    def __init__(self):
        super().__init__()
        self.Wx = nn.Linear(INPUTSIZE, 128)
        self.Ws = nn.Linear(128, 128)

    def forward(self, x, s = None):
        z = self.Wx(x)
        if not s == None:
            z = z + self.Ws(s)

        return f.tanh(z)

class RNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.cell = RNNCell()
        self.get_feature = GetFeature()

        self.fc1 = nn.Linear(128, 64)
        self.fc2 = nn.Linear(64, 2)


    def forward(self, frames):
        last_s = None
        for frame in frames:
            feature_vector = self.get_feature(frame)
            last_s = self.cell(feature_vector, last_s)


        last_s = f.relu(self.fc1(last_s))
        last_s = self.fc2(last_s)

        return last_s

model = RNN()

import torch.optim as optim

optimizer = optim.SGD(model.parameters(), lr = 0.01, momentum = 0.9)

loss_calculator = nn.CrossEntropyLoss()

for epoch in range(100):
    for id, (x, y) in enumerate(dataset):
        y_hat = model(x)
        loss = loss_calculator(y_hat, y)
        print(f"Epoch: {epoch} || example: {id}")
        print(y.numpy())
        print(torch.argmax(y_hat).numpy())
        print(loss.item())

        optimizer.zero_grad()

        loss.backward()

        optimizer.step()
# Out:
# Epoch: 0 || example: 0
# 0
# 1
# 0.7621915936470032
# Epoch: 0 || example: 1
# 0
# 0
# 0.43971604108810425
# Epoch: 0 || example: 2
# 0
# 0
# 0.316957950592041
# Epoch: 0 || example: 3
# 0
# 0
# 0.2311413288116455
# Epoch: 0 || example: 4
# 1
# 0
# 1.7848124504089355
# Epoch: 0 || example: 5
# 1
# 0
# 1.5745452642440796
# Epoch: 0 || example: 6
# 0
# 0
# 0.35038867592811584
# Epoch: 0 || example: 7
# 0
# 0
# 0.4374980628490448
# Epoch: 0 || example: 8
# 1
# 0
# 0.9729369878768921
# Epoch: 0 || example: 9
# 1
# 0
# 0.8053944706916809
# Epoch: 0 || example: 10
# 0
# 1
# 0.7786017656326294
# Epoch: 0 || example: 11
# 1
# 1
# 0.5532603859901428
# Epoch: 0 || example: 12
# 1
# 1
# 0.47397682070732117
# Epoch: 0 || example: 13
# 0
# 1
# 1.1245734691619873
# Epoch: 0 || example: 14
# 0
# 1
# 1.116947889328003
# Epoch: 0 || example: 15
# 1
# 1
# 0.4651242196559906
# Epoch: 0 || example: 16
# 0
# 1
# 0.9396517276763916
# Epoch: 0 || example: 17
# 1
# 1
# 0.582838773727417
# Epoch: 0 || example: 18
# 1
# 1
# 0.6208463907241821
# Epoch: 0 || example: 19
# 1
# 1
# 0.612571120262146
# Epoch: 0 || example: 20
# 1
# 1
# 0.564384400844574
# Epoch: 0 || example: 21
# 0
# 1
# 0.9431749582290649
# Epoch: 0 || example: 22
# 1
# 1
# 0.4799867570400238
# Epoch: 0 || example: 23
# 0
# 1
# 1.0288300514221191
# Epoch: 0 || example: 24
# 0
# 1
# 1.006288766860962
# Epoch: 0 || example: 25
# 0
# 1
# 0.9192425608634949
# Epoch: 0 || example: 26
# 0
# 1
# 0.8065063953399658
# Epoch: 0 || example: 27
# 1
# 0
# 0.6978199481964111
# Epoch: 0 || example: 28
# 1
# 0
# 0.750127375125885
# Epoch: 0 || example: 29
# 0
# 0
# 0.6340065002441406
# Epoch: 0 || example: 30
# 1
# 0
# 0.779384195804596
# Epoch: 0 || example: 31
# 0
# 0
# 0.6236751079559326
# Epoch: 0 || example: 32
# 1
# 0
# 0.7785137295722961
# Epoch: 0 || example: 33
# 0
# 0
# 0.6265207529067993
# Epoch: 0 || example: 34
# 1
# 0
# 0.7709252834320068
# Epoch: 0 || example: 35
# 0
# 0
# 0.6349781155586243
# Epoch: 0 || example: 36
# 0
# 0
# 0.6314684152603149
# Epoch: 0 || example: 37
# 0
# 0
# 0.6119449138641357
# Epoch: 0 || example: 38
# 0
# 0
# 0.5776724815368652
# Epoch: 0 || example: 39
# 0
# 0
# 0.5308099985122681
# Epoch: 0 || example: 40
# 0
# 0
# 0.47341132164001465
# Epoch: 0 || example: 41
# 0
# 0
# 0.40464112162590027
# Epoch: 0 || example: 42
# 1
# 0
# 1.27942955493927
# Epoch: 0 || example: 43
# 1
# 0
# 1.3429505825042725
# Epoch: 0 || example: 44
# 1
# 0
# 1.2738103866577148
# Epoch: 0 || example: 45
# 1
# 0
# 1.1227209568023682
# Epoch: 0 || example: 46
# 0
# 0
# 0.4802166521549225
# Epoch: 0 || example: 47
# 0
# 0
# 0.5334565043449402
# Epoch: 0 || example: 48
# 1
# 0
# 0.8451569080352783
# Epoch: 0 || example: 49
# 1
# 0
# 0.8115951418876648
# Epoch: 0 || example: 50
# 1
# 0
# 0.7861649394035339
# Epoch: 0 || example: 51
# 1
# 0
# 0.7672567367553711
# Epoch: 0 || example: 52
# 1
# 0
# 0.7460482120513916
# Epoch: 0 || example: 53
# 1
# 0
# 0.7221553325653076
# Epoch: 0 || example: 54
# 0
# 0
# 0.6903700232505798
# Epoch: 0 || example: 55
# 1
# 1
# 0.6777975559234619
# Epoch: 0 || example: 56
# 1
# 1
# 0.6570075154304504
# Epoch: 0 || example: 57
# 1
# 1
# 0.6341507434844971
# Epoch: 0 || example: 58
# 0
# 1
# 0.7842652797698975
# Epoch: 0 || example: 59
# 1
# 1
# 0.5931428670883179
# Epoch: 0 || example: 60
# 0
# 1
# 0.8277119994163513
# Epoch: 0 || example: 61
# 1
# 1
# 0.5629082918167114
# Epoch: 0 || example: 62
# 1
# 1
# 0.5482936501502991
# Epoch: 0 || example: 63
# 0
# 1
# 0.8863667249679565
# Epoch: 0 || example: 64
# 0
# 1
# 0.8998173475265503
# Epoch: 0 || example: 65
# 0
# 1
# 0.903672456741333
# Epoch: 0 || example: 66
# 0
# 1
# 0.8990325331687927
# Epoch: 0 || example: 67
# 1
# 1
# 0.5300592184066772
# Epoch: 0 || example: 68
# 0
# 1
# 0.8844265341758728
# Epoch: 0 || example: 69
# 1
# 1
# 0.5398651361465454
# Epoch: 0 || example: 70
# 1
# 1
# 0.5429205298423767
# Epoch: 0 || example: 71
# 0
# 1
# 0.8710479736328125
# Epoch: 0 || example: 72
# 0
# 1
# 0.8652404546737671
# Epoch: 0 || example: 73
# 0
# 1
# 0.8533703684806824
# Epoch: 0 || example: 74
# 1
# 1
# 0.5679794549942017
# Epoch: 0 || example: 75
# 0
# 1
# 0.8259012699127197
# Epoch: 0 || example: 76
# 0
# 1
# 0.810395359992981
# Epoch: 0 || example: 77
# 0
# 1
# 0.7905189990997314
# Epoch: 0 || example: 78
# 0
# 1
# 0.767038106918335
# Epoch: 0 || example: 79
# 1
# 1
# 0.6477653980255127
# Epoch: 0 || example: 80
# 0
# 1
# 0.7223928570747375
# Epoch: 0 || example: 81
# 1
# 1
# 0.6853591799736023
# Epoch: 0 || example: 82
# 1
# 0
# 0.6992970108985901
# Epoch: 0 || example: 83
# 1
# 0
# 0.7068953514099121
# Epoch: 0 || example: 84
# 1
# 0
# 0.7086232900619507
# Epoch: 0 || example: 85
# 0
# 0
# 0.6814025640487671
# Epoch: 0 || example: 86
# 1
# 0
# 0.7068050503730774
# Epoch: 0 || example: 87
# 0
# 0
# 0.6831235885620117
# Epoch: 0 || example: 88
# 1
# 0
# 0.7050994038581848
# Epoch: 0 || example: 89
# 1
# 0
# 0.7016316652297974
# Epoch: 0 || example: 90
# 1
# 0
# 0.6934642195701599
# Epoch: 0 || example: 91
# 1
# 1
# 0.6812160015106201
# Epoch: 0 || example: 92
# 0
# 1
# 0.7215714454650879
# Epoch: 0 || example: 93
# 0
# 1
# 0.7311598658561707
# Epoch: 0 || example: 94
# 1
# 1
# 0.6534796357154846
# Epoch: 0 || example: 95
# 0
# 1
# 0.7424430847167969
# Epoch: 0 || example: 96
# 0
# 1
# 0.7441688776016235
# Epoch: 0 || example: 97
# 0
# 1
# 0.7402206063270569
# Epoch: 0 || example: 98
# 0
# 1
# 0.7312401533126831
# Epoch: 0 || example: 99
# 1
# 1
# 0.6689978241920471
# Epoch: 0 || example: 100
# 0
# 1
# 0.7109780311584473
# Epoch: 0 || example: 101
# 1
# 1
# 0.6866780519485474
# Epoch: 0 || example: 102
# 0
# 1
# 0.6945398449897766
# Epoch: 0 || example: 103
# 1
# 0
# 0.7013847827911377
# Epoch: 0 || example: 104
# 0
# 0
# 0.6814178228378296
# Epoch: 0 || example: 105
# 1
# 0
# 0.7133221626281738
# Epoch: 0 || example: 106
# 0
# 0
# 0.6711598634719849
# Epoch: 0 || example: 107
# 1
# 0
# 0.7227286100387573
# Epoch: 0 || example: 108
# 1
# 0
# 0.7238447666168213
# Epoch: 0 || example: 109
# 1
# 0
# 0.7195518016815186
# Epoch: 0 || example: 110
# 1
# 0
# 0.7104713916778564
# Epoch: 0 || example: 111
# 1
# 0
# 0.6972468495368958
# Epoch: 0 || example: 112
# 1
# 1
# 0.6805219650268555
# Epoch: 0 || example: 113
# 0
# 1
# 0.7264435887336731
# Epoch: 0 || example: 114
# 1
# 1
# 0.6485437154769897
# Epoch: 0 || example: 115
# 1
# 1
# 0.6330556869506836
# Epoch: 0 || example: 116
# 1
# 1
# 0.6150245070457458
# Epoch: 0 || example: 117
# 0
# 1
# 0.8020028471946716
# Epoch: 0 || example: 118
# 1
# 1
# 0.5822179317474365
# Epoch: 0 || example: 119
# 1
# 1
# 0.5670700669288635
# Epoch: 0 || example: 120
# 0
# 1
# 0.8602401614189148
# Epoch: 0 || example: 121
# 0
# 1
# 0.8743460178375244
# Epoch: 0 || example: 122
# 0
# 1
# 0.880324125289917
# Epoch: 0 || example: 123
# 0
# 1
# 0.8788639307022095
# Epoch: 0 || example: 124
# 1
# 1
# 0.5423911213874817
# Epoch: 0 || example: 125
# 0
# 1
# 0.8683109879493713
# Epoch: 0 || example: 126
# 0
# 1
# 0.8594236969947815
# Epoch: 0 || example: 127
# 0
# 1
# 0.8448803424835205
# Epoch: 0 || example: 128
# 0
# 1
# 0.8254990577697754
# Epoch: 0 || example: 129
# 0
# 1
# 0.8020869493484497
# Epoch: 0 || example: 130
# 0
# 1
# 0.7754230499267578
# Epoch: 0 || example: 131
# 0
# 1
# 0.7462443709373474
# Epoch: 0 || example: 132
# 1
# 1
# 0.671535849571228
# Epoch: 0 || example: 133
# 0
# 0
# 0.6929705142974854
# Epoch: 0 || example: 134
# 0
# 0
# 0.6684597134590149
# Epoch: 0 || example: 135
# 1
# 0
# 0.7467256784439087
# Epoch: 0 || example: 136
# 1
# 0
# 0.7671468257904053
# Epoch: 0 || example: 137
# 1
# 0
# 0.7800239324569702
# Epoch: 0 || example: 138
# 1
# 0
# 0.7858246564865112
# Epoch: 0 || example: 139
# 0
# 0
# 0.6089137196540833
# Epoch: 0 || example: 140
# 0
# 0
# 0.6052829027175903
# Epoch: 0 || example: 141
# 1
# 0
# 0.798392653465271
# Epoch: 0 || example: 142
# 0
# 0
# 0.5962958335876465
# Epoch: 0 || example: 143
# 1
# 0
# 0.8071646690368652
# Epoch: 0 || example: 144
# 0
# 0
# 0.5908302068710327
# Epoch: 0 || example: 145
# 0
# 0
# 0.5868780016899109
# Epoch: 0 || example: 146
# 0
# 0
# 0.5794232487678528
# Epoch: 0 || example: 147
# 0
# 0
# 0.5689482092857361
# Epoch: 0 || example: 148
# 1
# 0
# 0.8522313833236694
# Epoch: 0 || example: 149
# 0
# 0
# 0.5492396950721741
# Epoch: 0 || example: 150
# 1
# 0
# 0.8744359612464905
# Epoch: 0 || example: 151
# 1
# 0
# 0.8795262575149536
# Epoch: 0 || example: 152
# 1
# 0
# 0.8772724866867065
# Epoch: 0 || example: 153
# 0
# 0
# 0.5440396666526794
# Epoch: 0 || example: 154
# 1
# 0
# 0.865410327911377
# Epoch: 0 || example: 155
# 1
# 0
# 0.8560017347335815
# Epoch: 0 || example: 156
# 0
# 0
# 0.56434166431427
# Epoch: 0 || example: 157
# 0
# 0
# 0.5708087086677551
# Epoch: 0 || example: 158
# 1
# 0
# 0.8298903703689575
# Epoch: 0 || example: 159
# 1
# 0
# 0.8211545944213867
# Epoch: 0 || example: 160
# 1
# 0
# 0.8071237802505493
# Epoch: 0 || example: 161
# 1
# 0
# 0.7885721325874329
# Epoch: 0 || example: 162
# 1
# 0
# 0.7662626504898071
# Epoch: 0 || example: 163
# 0
# 0
# 0.6475439071655273
# Epoch: 0 || example: 164
# 1
# 0
# 0.7235169410705566
# Epoch: 0 || example: 165
# 0
# 0
# 0.683515191078186
# Epoch: 0 || example: 166
# 1
# 1
# 0.6895650625228882
# Epoch: 0 || example: 167
# 0
# 1
# 0.7138687968254089
# Epoch: 0 || example: 168
# 0
# 1
# 0.7242556810379028
# Epoch: 0 || example: 169
# 1
# 1
# 0.6591445207595825
# Epoch: 0 || example: 170
# 1
# 1
# 0.651077151298523
# Epoch: 0 || example: 171
# 0
# 1
# 0.7500099539756775
# Epoch: 0 || example: 172
# 0
# 1
# 0.756177544593811
# Epoch: 0 || example: 173
# 1
# 1
# 0.6339113712310791
# Epoch: 0 || example: 174
# 0
# 1
# 0.7610490322113037
# Epoch: 0 || example: 175
# 0
# 1
# 0.7598227262496948
# Epoch: 0 || example: 176
# 1
# 1
# 0.6366093158721924
# Epoch: 0 || example: 177
# 0
# 1
# 0.752001941204071
# Epoch: 0 || example: 178
# 1
# 1
# 0.6434274911880493
# Epoch: 0 || example: 179
# 1
# 1
# 0.6442185044288635
# Epoch: 0 || example: 180
# 1
# 1
# 0.6404275298118591
# Epoch: 0 || example: 181
# 0
# 1
# 0.7576158046722412
# Epoch: 0 || example: 182
# 0
# 1
# 0.7599382996559143
# Epoch: 0 || example: 183
# 0
# 1
# 0.7563693523406982
# Epoch: 0 || example: 184
# 1
# 1
# 0.6415380239486694
# Epoch: 0 || example: 185
# 1
# 1
# 0.6441558003425598
# Epoch: 0 || example: 186
# 1
# 1
# 0.6420074105262756
# Epoch: 0 || example: 187
# 0
# 1
# 0.7541983127593994
# Epoch: 0 || example: 188
# 0
# 1
# 0.7550483345985413
# Epoch: 0 || example: 189
# 0
# 1
# 0.7502058744430542
# Epoch: 0 || example: 190
# 0
# 1
# 0.7403310537338257
# Epoch: 0 || example: 191
# 0
# 1
# 0.7261053323745728
# Epoch: 0 || example: 192
# 1
# 1
# 0.6783081293106079
# Epoch: 0 || example: 193
# 1
# 1
# 0.6890131235122681
# Epoch: 0 || example: 194
# 0
# 0
# 0.6925419569015503
# Epoch: 0 || example: 195
# 1
# 0
# 0.703071653842926
# Epoch: 0 || example: 196
# 0
# 0
# 0.6800643801689148
# Epoch: 0 || example: 197
# 1
# 0
# 0.7144371867179871
# Epoch: 0 || example: 198
# 1
# 0
# 0.716484785079956
# Epoch: 0 || example: 199
# 1
# 0
# 0.7131016254425049
# Epoch: 0 || example: 200
# 0
# 0
# 0.6815359592437744
# Epoch: 1 || example: 0
# 0
# 0
# 0.6838417053222656
# Epoch: 1 || example: 1
# 0
# 0
# 0.6810165047645569
# Epoch: 1 || example: 2
# 0
# 0
# 0.6736268401145935
# Epoch: 1 || example: 3
# 0
# 0
# 0.6622647047042847
# Epoch: 1 || example: 4
# 1
# 0
# 0.7409493923187256
# Epoch: 1 || example: 5
# 1
# 0
# 0.7499561309814453
# Epoch: 1 || example: 6
# 0
# 0
# 0.6370934247970581
# Epoch: 1 || example: 7
# 0
# 0
# 0.6306104063987732
# Epoch: 1 || example: 8
# 1
# 0
# 0.7715109586715698
# Epoch: 1 || example: 9
# 1
# 0
# 0.7762800455093384
# Epoch: 1 || example: 10
# 0
# 0
# 0.6177019476890564
# Epoch: 1 || example: 11
# 1
# 0
# 0.7783531546592712
# Epoch: 1 || example: 12
# 1
# 0
# 0.7757517099380493
# Epoch: 1 || example: 13
# 0
# 0
# 0.6238407492637634
# Epoch: 1 || example: 14
# 0
# 0
# 0.6258535981178284
# Epoch: 1 || example: 15
# 1
# 0
# 0.7681924700737
# Epoch: 1 || example: 16
# 0
# 0
# 0.6260642409324646
# Epoch: 1 || example: 17
# 1
# 0
# 0.7672147750854492
# Epoch: 1 || example: 18
# 1
# 0
# 0.7634263634681702
# Epoch: 1 || example: 19
# 1
# 0
# 0.7543570399284363
# Epoch: 1 || example: 20
# 1
# 0
# 0.7406995892524719
# Epoch: 1 || example: 21
# 0
# 0
# 0.6640174984931946
# Epoch: 1 || example: 22
# 1
# 0
# 0.7125349640846252
# Epoch: 1 || example: 23
# 0
# 0
# 0.6883781552314758
# Epoch: 1 || example: 24
# 0
# 1
# 0.6963765621185303
# Epoch: 1 || example: 25
# 0
# 1
# 0.6985740661621094
# Epoch: 1 || example: 26
# 0
# 1
# 0.6955044269561768
# Epoch: 1 || example: 27
# 1
# 0
# 0.6985711455345154
# Epoch: 1 || example: 28
# 1
# 0
# 0.7005441188812256
# Epoch: 1 || example: 29
# 0
# 0
# 0.6890583038330078
# Epoch: 1 || example: 30
# 1
# 0
# 0.6992974877357483
# Epoch: 1 || example: 31
# 0
# 0
# 0.6902197599411011
# Epoch: 1 || example: 32
# 1
# 0
# 0.6981971263885498
# Epoch: 1 || example: 33
# 0
# 0
# 0.6912420392036438
# Epoch: 1 || example: 34
# 1
# 0
# 0.6972358226776123
# Epoch: 1 || example: 35
# 0
# 0
# 0.6921319365501404
# Epoch: 1 || example: 36
# 0
# 0
# 0.6898998022079468
# Epoch: 1 || example: 37
# 0
# 0
# 0.6829500794410706
# Epoch: 1 || example: 38
# 0
# 0
# 0.6718826293945312
# Epoch: 1 || example: 39
# 0
# 0
# 0.6573039293289185
# Epoch: 1 || example: 40
# 0
# 0
# 0.6398105025291443
# Epoch: 1 || example: 41
# 0
# 0
# 0.6199743747711182
# Epoch: 1 || example: 42
# 1
# 0
# 0.7979013919830322
# Epoch: 1 || example: 43
# 1
# 0
# 0.8154540657997131
# Epoch: 1 || example: 44
# 1
# 0
# 0.8251828551292419
# Epoch: 1 || example: 45
# 1
# 0
# 0.827661395072937
# Epoch: 1 || example: 46
# 0
# 0
# 0.5777942538261414
# Epoch: 1 || example: 47
# 0
# 0
# 0.5768230557441711
# Epoch: 1 || example: 48
# 1
# 0
# 0.830863356590271
# Epoch: 1 || example: 49
# 1
# 0
# 0.8299589157104492
# Epoch: 1 || example: 50
# 1
# 0
# 0.8228048086166382
# Epoch: 1 || example: 51
# 1
# 0
# 0.8101572394371033
# Epoch: 1 || example: 52
# 1
# 0
# 0.7927889823913574
# Epoch: 1 || example: 53
# 1
# 0
# 0.7714662551879883
# Epoch: 1 || example: 54
# 0
# 0
# 0.6421085596084595
# Epoch: 1 || example: 55
# 1
# 0
# 0.7302029728889465
# Epoch: 1 || example: 56
# 1
# 0
# 0.7100839614868164
# Epoch: 1 || example: 57
# 1
# 1
# 0.6872384548187256
# Epoch: 1 || example: 58
# 0
# 1
# 0.7249849438667297
# Epoch: 1 || example: 59
# 1
# 1
# 0.6452823877334595
# Epoch: 1 || example: 60
# 0
# 1
# 0.7653516530990601
# Epoch: 1 || example: 61
# 1
# 1
# 0.6135346293449402
# Epoch: 1 || example: 62
# 1
# 1
# 0.5984986424446106
# Epoch: 1 || example: 63
# 0
# 1
# 0.8192026019096375
# Epoch: 1 || example: 64
# 0
# 1
# 0.8325372934341431
# Epoch: 1 || example: 65
# 0
# 1
# 0.838227391242981
# Epoch: 1 || example: 66
# 0
# 1
# 0.8369185924530029
# Epoch: 1 || example: 67
# 1
# 1
# 0.57330322265625
# Epoch: 1 || example: 68
# 0
# 1
# 0.8274492025375366
# Epoch: 1 || example: 69
# 1
# 1
# 0.5810282826423645
# Epoch: 1 || example: 70
# 1
# 1
# 0.5828056335449219
# Epoch: 1 || example: 71
# 0
# 1
# 0.820102334022522
# Epoch: 1 || example: 72
# 0
# 1
# 0.8164669275283813
# Epoch: 1 || example: 73
# 0
# 1
# 0.8070080876350403
# Epoch: 1 || example: 74
# 1
# 1
# 0.6027964949607849
# Epoch: 1 || example: 75
# 0
# 1
# 0.7844629883766174
# Epoch: 1 || example: 76
# 0
# 1
# 0.7714337110519409
# Epoch: 1 || example: 77
# 0
# 1
# 0.7541218996047974
# Epoch: 1 || example: 78
# 0
# 1
# 0.7332474589347839
# Epoch: 1 || example: 79
# 1
# 1
# 0.6770536303520203
# Epoch: 1 || example: 80
# 0
# 1
# 0.6934995651245117
# Epoch: 1 || example: 81
# 1
# 0
# 0.712261438369751
# Epoch: 1 || example: 82
# 1
# 0
# 0.7248327732086182
# Epoch: 1 || example: 83
# 1
# 0
# 0.7309151291847229
# Epoch: 1 || example: 84
# 1
# 0
# 0.7310272455215454
# Epoch: 1 || example: 85
# 0
# 0
# 0.6615621447563171
# Epoch: 1 || example: 86
# 1
# 0
# 0.7260307669639587
# Epoch: 1 || example: 87
# 0
# 0
# 0.6660911440849304
# Epoch: 1 || example: 88
# 1
# 0
# 0.7213952541351318
# Epoch: 1 || example: 89
# 1
# 0
# 0.716519832611084
# Epoch: 1 || example: 90
# 1
# 0
# 0.7069526314735413
# Epoch: 1 || example: 91
# 1
# 0
# 0.6933351755142212
# Epoch: 1 || example: 92
# 0
# 1
# 0.710275411605835
# Epoch: 1 || example: 93
# 0
# 1
# 0.7208752036094666
# Epoch: 1 || example: 94
# 1
# 1
# 0.6620945930480957
# Epoch: 1 || example: 95
# 0
# 1
# 0.7341228723526001
# Epoch: 1 || example: 96
# 0
# 1
# 0.7367848753929138
# Epoch: 1 || example: 97
# 0
# 1
# 0.7337518930435181
# Epoch: 1 || example: 98
# 0
# 1
# 0.7256507277488708
# Epoch: 1 || example: 99
# 1
# 1
# 0.6735495924949646
# Epoch: 1 || example: 100
# 0
# 1
# 0.706957221031189
# Epoch: 1 || example: 101
# 1
# 1
# 0.6899746060371399
# Epoch: 1 || example: 102
# 0
# 0
# 0.6918253302574158
# Epoch: 1 || example: 103
# 1
# 0
# 0.703567385673523
# Epoch: 1 || example: 104
# 0
# 0
# 0.6797837615013123
# Epoch: 1 || example: 105
# 1
# 0
# 0.7145366668701172
# Epoch: 1 || example: 106
# 0
# 0
# 0.6704116463661194
# Epoch: 1 || example: 107
# 1
# 0
# 0.7231194972991943
# Epoch: 1 || example: 108
# 1
# 0
# 0.7238762974739075
# Epoch: 1 || example: 109
# 1
# 0
# 0.719260573387146
# Epoch: 1 || example: 110
# 1
# 0
# 0.709896445274353
# Epoch: 1 || example: 111
# 1
# 0
# 0.6964279413223267
# Epoch: 1 || example: 112
# 1
# 1
# 0.6794983148574829
# Epoch: 1 || example: 113
# 0
# 1
# 0.7277161478996277
# Epoch: 1 || example: 114
# 1
# 1
# 0.6472086310386658
# Epoch: 1 || example: 115
# 1
# 1
# 0.6316078305244446
# Epoch: 1 || example: 116
# 1
# 1
# 0.6134940981864929
# Epoch: 1 || example: 117
# 0
# 1
# 0.803956151008606
# Epoch: 1 || example: 118
# 1
# 1
# 0.5805846452713013
# Epoch: 1 || example: 119
# 1
# 1
# 0.5654116868972778
# Epoch: 1 || example: 120
# 0
# 1
# 0.8625123500823975
# Epoch: 1 || example: 121
# 0
# 1
# 0.8766825199127197
# Epoch: 1 || example: 122
# 0
# 1
# 0.8826961517333984
# Epoch: 1 || example: 123
# 0
# 1
# 0.8812450170516968
# Epoch: 1 || example: 124
# 1
# 1
# 0.5406907796859741
# Epoch: 1 || example: 125
# 0
# 1
# 0.8706603050231934
# Epoch: 1 || example: 126
# 0
# 1
# 0.8617352247238159
# Epoch: 1 || example: 127
# 0
# 1
# 0.8471357822418213
# Epoch: 1 || example: 128
# 0
# 1
# 0.827682614326477
# Epoch: 1 || example: 129
# 0
# 1
# 0.8041854500770569
# Epoch: 1 || example: 130
# 0
# 1
# 0.77742600440979
# Epoch: 1 || example: 131
# 0
# 1
# 0.7481436729431152
# Epoch: 1 || example: 132
# 1
# 1
# 0.6698257327079773
# Epoch: 1 || example: 133
# 0
# 1
# 0.6946638226509094
# Epoch: 1 || example: 134
# 0
# 0
# 0.6700520515441895
# Epoch: 1 || example: 135
# 1
# 0
# 0.7450757026672363
# Epoch: 1 || example: 136
# 1
# 0
# 0.7655353546142578
# Epoch: 1 || example: 137
# 1
# 0
# 0.7784650921821594
# Epoch: 1 || example: 138
# 1
# 0
# 0.7843297123908997
# Epoch: 1 || example: 139
# 0
# 0
# 0.6101077795028687
# Epoch: 1 || example: 140
# 0
# 0
# 0.6064118146896362
# Epoch: 1 || example: 141
# 1
# 0
# 0.7970989346504211
# Epoch: 1 || example: 142
# 0
# 0
# 0.5972954034805298
# Epoch: 1 || example: 143
# 1
# 0
# 0.8060039281845093
# Epoch: 1 || example: 144
# 0
# 0
# 0.5917101502418518
# Epoch: 1 || example: 145
# 0
# 0
# 0.5876992344856262
# Epoch: 1 || example: 146
# 0
# 0
# 0.5801841616630554
# Epoch: 1 || example: 147
# 0
# 0
# 0.5696486234664917
# Epoch: 1 || example: 148
# 1
# 0
# 0.8513705730438232
# Epoch: 1 || example: 149
# 0
# 0
# 0.5498287081718445
# Epoch: 1 || example: 150
# 1
# 0
# 0.8736850023269653
# Epoch: 1 || example: 151
# 1
# 0
# 0.8788310289382935
# Epoch: 1 || example: 152
# 1
# 0
# 0.8766344785690308
# Epoch: 1 || example: 153
# 0
# 0
# 0.5444598197937012
# Epoch: 1 || example: 154
# 1
# 0
# 0.8648812174797058
# Epoch: 1 || example: 155
# 1
# 0
# 0.8555240631103516
# Epoch: 1 || example: 156
# 0
# 0
# 0.5646659731864929
# Epoch: 1 || example: 157
# 0
# 0
# 0.5711033344268799
# Epoch: 1 || example: 158
# 1
# 0
# 0.8295482397079468
# Epoch: 1 || example: 159
# 1
# 0
# 0.8208519816398621
# Epoch: 1 || example: 160
# 1
# 0
# 0.8068591356277466
# Epoch: 1 || example: 161
# 1
# 0
# 0.7883434295654297
# Epoch: 1 || example: 162
# 1
# 0
# 0.7660674452781677
# Epoch: 1 || example: 163
# 0
# 0
# 0.6476932764053345
# Epoch: 1 || example: 164
# 1
# 0
# 0.7233800292015076
# Epoch: 1 || example: 165
# 0
# 0
# 0.6836249828338623
# Epoch: 1 || example: 166
# 1
# 1
# 0.6894749402999878
# Epoch: 1 || example: 167
# 0
# 1
# 0.7139419317245483
# Epoch: 1 || example: 168
# 0
# 1
# 0.7243116497993469
# Epoch: 1 || example: 169
# 1
# 1
# 0.6591073870658875
# Epoch: 1 || example: 170
# 1
# 1
# 0.6510541439056396
# Epoch: 1 || example: 171
# 0
# 1
# 0.7500214576721191
# Epoch: 1 || example: 172
# 0
# 1
# 0.7561764717102051
# Epoch: 1 || example: 173
# 1
# 1
# 0.6339223384857178
# Epoch: 1 || example: 174
# 0
# 1
# 0.7610265016555786
# Epoch: 1 || example: 175
# 0
# 1
# 0.7597912549972534
# Epoch: 1 || example: 176
# 1
# 1
# 0.6366443634033203
# Epoch: 1 || example: 177
# 0
# 1
# 0.7519557476043701
# Epoch: 1 || example: 178
# 1
# 1
# 0.6434744000434875
# Epoch: 1 || example: 179
# 1
# 1
# 0.6442700624465942
# Epoch: 1 || example: 180
# 1
# 1
# 0.6404828429222107
# Epoch: 1 || example: 181
# 0
# 1
# 0.7575502395629883
# Epoch: 1 || example: 182
# 0
# 1
# 0.7598695755004883
# Epoch: 1 || example: 183
# 0
# 1
# 0.7562985420227051
# Epoch: 1 || example: 184
# 1
# 1
# 0.6416027545928955
# Epoch: 1 || example: 185
# 1
# 1
# 0.6442217826843262
# Epoch: 1 || example: 186
# 1
# 1
# 0.6420737504959106
# Epoch: 1 || example: 187
# 0
# 1
# 0.7541237473487854
# Epoch: 1 || example: 188
# 0
# 1
# 0.7549738883972168
# Epoch: 1 || example: 189
# 0
# 1
# 0.7501322627067566
# Epoch: 1 || example: 190
# 0
# 1
# 0.7402589321136475
# Epoch: 1 || example: 191
# 0
# 1
# 0.7260352373123169
# Epoch: 1 || example: 192
# 1
# 1
# 0.6783738136291504
# Epoch: 1 || example: 193
# 1
# 1
# 0.6890780329704285
# Epoch: 1 || example: 194
# 0
# 0
# 0.6924784183502197
# Epoch: 1 || example: 195
# 1
# 0
# 0.7031338810920715
# Epoch: 1 || example: 196
# 0
# 0
# 0.6800054311752319
# Epoch: 1 || example: 197
# 1
# 0
# 0.7144961357116699
# Epoch: 1 || example: 198
# 1
# 0
# 0.7165417075157166
# Epoch: 1 || example: 199
# 1
# 0
# 0.7131561040878296
# Epoch: 1 || example: 200
# 0
# 0
# 0.6814854145050049
# Epoch: 2 || example: 0
# 0
# 0
# 0.6837931871414185
# Epoch: 2 || example: 1
# 0
# 0
# 0.6809703707695007
# Epoch: 2 || example: 2
# 0
# 0
# 0.6735833883285522
# Epoch: 2 || example: 3
# 0
# 0
# 0.6622239351272583
# Epoch: 2 || example: 4
# 1
# 0
# 0.7409910559654236
# Epoch: 2 || example: 5
# 1
# 0
# 0.749995768070221
# Epoch: 2 || example: 6
# 0
# 0
# 0.6370601654052734
# Epoch: 2 || example: 7
# 0
# 0
# 0.6305792927742004
# Epoch: 2 || example: 8
# 1
# 0
# 0.7715443968772888
# Epoch: 2 || example: 9
# 1
# 0
# 0.7763113975524902
# Epoch: 2 || example: 10
# 0
# 0
# 0.6176769733428955
# Epoch: 2 || example: 11
# 1
# 0
# 0.7783803939819336
# Epoch: 2 || example: 12
# 1
# 0
# 0.775776743888855
# Epoch: 2 || example: 13
# 0
# 0
# 0.6238208413124084
# Epoch: 2 || example: 14
# 0
# 0
# 0.6258352398872375
# Epoch: 2 || example: 15
# 1
# 0
# 0.7682119011878967
# Epoch: 2 || example: 16
# 0
# 0
# 0.6260489225387573
# Epoch: 2 || example: 17
# 1
# 0
# 0.7672308683395386
# Epoch: 2 || example: 18
# 1
# 0
# 0.7634409666061401
# Epoch: 2 || example: 19
# 1
# 0
# 0.7543699741363525
# Epoch: 2 || example: 20
# 1
# 0
# 0.7407110929489136
# Epoch: 2 || example: 21
# 0
# 0
# 0.6640079021453857
# Epoch: 2 || example: 22
# 1
# 0
# 0.712543785572052
# Epoch: 2 || example: 23
# 0
# 0
# 0.6883706450462341
# Epoch: 2 || example: 24
# 0
# 1
# 0.6963698863983154
# Epoch: 2 || example: 25
# 0
# 1
# 0.6985683441162109
# Epoch: 2 || example: 26
# 0
# 1
# 0.6954995393753052
# Epoch: 2 || example: 27
# 1
# 0
# 0.6985753178596497
# Epoch: 2 || example: 28
# 1
# 0
# 0.700547456741333
# Epoch: 2 || example: 29
# 0
# 0
# 0.6890556812286377
# Epoch: 2 || example: 30
# 1
# 0
# 0.6992995142936707
# Epoch: 2 || example: 31
# 0
# 0
# 0.6902183294296265
# Epoch: 2 || example: 32
# 1
# 0
# 0.6981979608535767
# Epoch: 2 || example: 33
# 0
# 0
# 0.6912416219711304
# Epoch: 2 || example: 34
# 1
# 0
# 0.6972357630729675
# Epoch: 2 || example: 35
# 0
# 0
# 0.692132294178009
# Epoch: 2 || example: 36
# 0
# 0
# 0.6899005174636841
# Epoch: 2 || example: 37
# 0
# 0
# 0.6829510927200317
# Epoch: 2 || example: 38
# 0
# 0
# 0.6718838214874268
# Epoch: 2 || example: 39
# 0
# 0
# 0.6573054194450378
# Epoch: 2 || example: 40
# 0
# 0
# 0.6398121118545532
# Epoch: 2 || example: 41
# 0
# 0
# 0.6199761629104614
# Epoch: 2 || example: 42
# 1
# 0
# 0.7978991270065308
# Epoch: 2 || example: 43
# 1
# 0
# 0.8154516220092773
# Epoch: 2 || example: 44
# 1
# 0
# 0.8251802921295166
# Epoch: 2 || example: 45
# 1
# 0
# 0.8276586532592773
# Epoch: 2 || example: 46
# 0
# 0
# 0.5777963399887085
# Epoch: 2 || example: 47
# 0
# 0
# 0.5768252015113831
# Epoch: 2 || example: 48
# 1
# 0
# 0.8308606147766113
# Epoch: 2 || example: 49
# 1
# 0
# 0.8299560546875
# Epoch: 2 || example: 50
# 1
# 0
# 0.8228018879890442
# Epoch: 2 || example: 51
# 1
# 0
# 0.810154378414154
# Epoch: 2 || example: 52
# 1
# 0
# 0.7927863001823425
# Epoch: 2 || example: 53
# 1
# 0
# 0.7714636921882629
# Epoch: 2 || example: 54
# 0
# 0
# 0.6421108245849609
# Epoch: 2 || example: 55
# 1
# 0
# 0.7302005887031555
# Epoch: 2 || example: 56
# 1
# 0
# 0.7100816965103149
# Epoch: 2 || example: 57
# 1
# 1
# 0.6872361898422241
# Epoch: 2 || example: 58
# 0
# 1
# 0.7249871492385864
# Epoch: 2 || example: 59
# 1
# 1
# 0.6452804803848267
# Epoch: 2 || example: 60
# 0
# 1
# 0.765353798866272
# Epoch: 2 || example: 61
# 1
# 1
# 0.6135329604148865
# Epoch: 2 || example: 62
# 1
# 1
# 0.5984969735145569
# Epoch: 2 || example: 63
# 0
# 1
# 0.8192046880722046
# Epoch: 2 || example: 64
# 0
# 1
# 0.8325390815734863
# Epoch: 2 || example: 65
# 0
# 1
# 0.8382291793823242
# Epoch: 2 || example: 66
# 0
# 1
# 0.8369202613830566
# Epoch: 2 || example: 67
# 1
# 1
# 0.5733019709587097
# Epoch: 2 || example: 68
# 0
# 1
# 0.8274507522583008
# Epoch: 2 || example: 69
# 1
# 1
# 0.5810271501541138
# Epoch: 2 || example: 70
# 1
# 1
# 0.5828046202659607
# Epoch: 2 || example: 71
# 0
# 1
# 0.820103645324707
# Epoch: 2 || example: 72
# 0
# 1
# 0.8164681196212769
# Epoch: 2 || example: 73
# 0
# 1
# 0.807009220123291
# Epoch: 2 || example: 74
# 1
# 1
# 0.6027956604957581
# Epoch: 2 || example: 75
# 0
# 1
# 0.7844638824462891
# Epoch: 2 || example: 76
# 0
# 1
# 0.7714345455169678
# Epoch: 2 || example: 77
# 0
# 1
# 0.7541226744651794
# Epoch: 2 || example: 78
# 0
# 1
# 0.7332481145858765
# Epoch: 2 || example: 79
# 1
# 1
# 0.6770530343055725
# Epoch: 2 || example: 80
# 0
# 1
# 0.6935001611709595
# Epoch: 2 || example: 81
# 1
# 0
# 0.7122609615325928
# Epoch: 2 || example: 82
# 1
# 0
# 0.72483229637146
# Epoch: 2 || example: 83
# 1
# 0
# 0.7309147119522095
# Epoch: 2 || example: 84
# 1
# 0
# 0.7310268878936768
# Epoch: 2 || example: 85
# 0
# 0
# 0.6615623831748962
# Epoch: 2 || example: 86
# 1
# 0
# 0.7260304093360901
# Epoch: 2 || example: 87
# 0
# 0
# 0.6660914421081543
# Epoch: 2 || example: 88
# 1
# 0
# 0.7213950753211975
# Epoch: 2 || example: 89
# 1
# 0
# 0.7165197134017944
# Epoch: 2 || example: 90
# 1
# 0
# 0.7069523930549622
# Epoch: 2 || example: 91
# 1
# 0
# 0.6933350563049316
# Epoch: 2 || example: 92
# 0
# 1
# 0.7102755308151245
# Epoch: 2 || example: 93
# 0
# 1
# 0.7208752632141113
# Epoch: 2 || example: 94
# 1
# 1
# 0.6620945930480957
# Epoch: 2 || example: 95
# 0
# 1
# 0.7341228127479553
# Epoch: 2 || example: 96
# 0
# 1
# 0.7367849349975586
# Epoch: 2 || example: 97
# 0
# 1
# 0.7337518930435181
# Epoch: 2 || example: 98
# 0
# 1
# 0.7256507277488708
# Epoch: 2 || example: 99
# 1
# 1
# 0.6735495924949646
# Epoch: 2 || example: 100
# 0
# 1
# 0.706957221031189
# Epoch: 2 || example: 101
# 1
# 1
# 0.6899746060371399
# Epoch: 2 || example: 102
# 0
# 0
# 0.691825270652771
# Epoch: 2 || example: 103
# 1
# 0
# 0.7035674452781677
# Epoch: 2 || example: 104
# 0
# 0
# 0.6797836422920227
# Epoch: 2 || example: 105
# 1
# 0
# 0.714536726474762
# Epoch: 2 || example: 106
# 0
# 0
# 0.6704115867614746
# Epoch: 2 || example: 107
# 1
# 0
# 0.7231194972991943
# Epoch: 2 || example: 108
# 1
# 0
# 0.723876416683197
# Epoch: 2 || example: 109
# 1
# 0
# 0.7192606329917908
# Epoch: 2 || example: 110
# 1
# 0
# 0.709896445274353
# Epoch: 2 || example: 111
# 1
# 0
# 0.6964280009269714
# Epoch: 2 || example: 112
# 1
# 1
# 0.6794984340667725
# Epoch: 2 || example: 113
# 0
# 1
# 0.7277160882949829
# Epoch: 2 || example: 114
# 1
# 1
# 0.6472086906433105
# Epoch: 2 || example: 115
# 1
# 1
# 0.6316079497337341
# Epoch: 2 || example: 116
# 1
# 1
# 0.6134941577911377
# Epoch: 2 || example: 117
# 0
# 1
# 0.8039559721946716
# Epoch: 2 || example: 118
# 1
# 1
# 0.5805847644805908
# Epoch: 2 || example: 119
# 1
# 1
# 0.5654117465019226
# Epoch: 2 || example: 120
# 0
# 1
# 0.8625123500823975
# Epoch: 2 || example: 121
# 0
# 1
# 0.8766824007034302
# Epoch: 2 || example: 122
# 0
# 1
# 0.8826960325241089
# Epoch: 2 || example: 123
# 0
# 1
# 0.8812448978424072
# Epoch: 2 || example: 124
# 1
# 1
# 0.5406907796859741
# Epoch: 2 || example: 125
# 0
# 1
# 0.8706601858139038
# Epoch: 2 || example: 126
# 0
# 1
# 0.8617351055145264
# Epoch: 2 || example: 127
# 0
# 1
# 0.847135603427887
# Epoch: 2 || example: 128
# 0
# 1
# 0.8276824951171875
# Epoch: 2 || example: 129
# 0
# 1
# 0.8041855096817017
# Epoch: 2 || example: 130
# 0
# 1
# 0.7774258852005005
# Epoch: 2 || example: 131
# 0
# 1
# 0.7481435537338257
# Epoch: 2 || example: 132
# 1
# 1
# 0.6698258519172668
# Epoch: 2 || example: 133
# 0
# 1
# 0.6946637034416199
# Epoch: 2 || example: 134
# 0
# 0
# 0.6700519919395447
# Epoch: 2 || example: 135
# 1
# 0
# 0.7450757622718811
# Epoch: 2 || example: 136
# 1
# 0
# 0.7655354142189026
# Epoch: 2 || example: 137
# 1
# 0
# 0.7784650921821594
# Epoch: 2 || example: 138
# 1
# 0
# 0.7843297719955444
# Epoch: 2 || example: 139
# 0
# 0
# 0.6101077795028687
# Epoch: 2 || example: 140
# 0
# 0
# 0.6064118146896362
# Epoch: 2 || example: 141
# 1
# 0
# 0.7970989942550659
# Epoch: 2 || example: 142
# 0
# 0
# 0.5972954034805298
# Epoch: 2 || example: 143
# 1
# 0
# 0.8060040473937988
# Epoch: 2 || example: 144
# 0
# 0
# 0.5917100310325623
# Epoch: 2 || example: 145
# 0
# 0
# 0.5876992344856262
# Epoch: 2 || example: 146
# 0
# 0
# 0.5801841616630554
# Epoch: 2 || example: 147
# 0
# 0
# 0.5696486234664917
# Epoch: 2 || example: 148
# 1
# 0
# 0.8513705730438232
# Epoch: 2 || example: 149
# 0
# 0
# 0.5498286485671997
# Epoch: 2 || example: 150
# 1
# 0
# 0.8736850619316101
# Epoch: 2 || example: 151
# 1
# 0
# 0.8788310885429382
# Epoch: 2 || example: 152
# 1
# 0
# 0.8766345381736755
# Epoch: 2 || example: 153
# 0
# 0
# 0.5444598197937012
# Epoch: 2 || example: 154
# 1
# 0
# 0.8648812174797058
# Epoch: 2 || example: 155
# 1
# 0
# 0.8555240631103516
# Epoch: 2 || example: 156
# 0
# 0
# 0.5646659731864929
# Epoch: 2 || example: 157
# 0
# 0
# 0.5711033344268799
# Epoch: 2 || example: 158
# 1
# 0
# 0.8295482397079468
# Epoch: 2 || example: 159
# 1
# 0
# 0.8208519816398621
# Epoch: 2 || example: 160
# 1
# 0
# 0.8068591356277466
# Epoch: 2 || example: 161
# 1
# 0
# 0.7883433699607849
# Epoch: 2 || example: 162
# 1
# 0
# 0.7660675048828125
# Epoch: 2 || example: 163
# 0
# 0
# 0.6476932764053345
# Epoch: 2 || example: 164
# 1
# 0
# 0.7233800292015076
# Epoch: 2 || example: 165
# 0
# 0
# 0.6836249828338623
# Epoch: 2 || example: 166
# 1
# 1
# 0.6894749402999878
# Epoch: 2 || example: 167
# 0
# 1
# 0.7139419317245483
# Epoch: 2 || example: 168
# 0
# 1
# 0.7243116497993469
# Epoch: 2 || example: 169
# 1
# 1
# 0.6591073870658875
# Epoch: 2 || example: 170
# 1
# 1
# 0.6510541439056396
# Epoch: 2 || example: 171
# 0
# 1
# 0.7500214576721191
# Epoch: 2 || example: 172
# 0
# 1
# 0.7561764717102051
# Epoch: 2 || example: 173
# 1
# 1
# 0.6339223384857178
# Epoch: 2 || example: 174
# 0
# 1
# 0.7610265016555786
# Epoch: 2 || example: 175
# 0
# 1
# 0.7597912549972534
# Epoch: 2 || example: 176
# 1
# 1
# 0.6366443634033203
# Epoch: 2 || example: 177
# 0
# 1
# 0.7519557476043701
# Epoch: 2 || example: 178
# 1
# 1
# 0.6434744000434875
# Epoch: 2 || example: 179
# 1
# 1
# 0.6442700624465942
# Epoch: 2 || example: 180
# 1
# 1
# 0.6404828429222107
# Epoch: 2 || example: 181
# 0
# 1
# 0.7575502395629883
# Epoch: 2 || example: 182
# 0
# 1
# 0.7598695755004883
# Epoch: 2 || example: 183
# 0
# 1
# 0.7562985420227051
# Epoch: 2 || example: 184
# 1
# 1
# 0.6416027545928955
# Epoch: 2 || example: 185
# 1
# 1
# 0.6442217826843262
# Epoch: 2 || example: 186
# 1
# 1
# 0.6420737504959106
# Epoch: 2 || example: 187
# 0
# 1
# 0.7541237473487854
# Epoch: 2 || example: 188
# 0
# 1
# 0.7549738883972168
# Epoch: 2 || example: 189
# 0
# 1
# 0.7501322627067566
# Epoch: 2 || example: 190
# 0
# 1
# 0.7402589321136475
# Epoch: 2 || example: 191
# 0
# 1
# 0.7260352373123169
# Epoch: 2 || example: 192
# 1
# 1
# 0.6783738136291504
# Epoch: 2 || example: 193
# 1
# 1
# 0.6890780329704285
# Epoch: 2 || example: 194
# 0
# 0
# 0.6924784183502197
# Epoch: 2 || example: 195
# 1
# 0
# 0.7031338810920715
# Epoch: 2 || example: 196
# 0
# 0
# 0.6800054311752319
# Epoch: 2 || example: 197
# 1
# 0
# 0.7144961357116699
# Epoch: 2 || example: 198
# 1
# 0
# 0.7165417075157166
# Epoch: 2 || example: 199
# 1
# 0
# 0.7131561040878296
# Epoch: 2 || example: 200
# 0
# 0
# 0.6814854145050049
# Epoch: 3 || example: 0
# 0
# 0
# 0.6837931871414185
# Epoch: 3 || example: 1
# 0
# 0
# 0.6809703707695007
# Epoch: 3 || example: 2
# 0
# 0
# 0.6735833883285522
# Epoch: 3 || example: 3
# 0
# 0
# 0.6622239351272583
# Epoch: 3 || example: 4
# 1
# 0
# 0.7409910559654236
# Epoch: 3 || example: 5
# 1
# 0
# 0.749995768070221
# Epoch: 3 || example: 6
# 0
# 0
# 0.6370601654052734
# Epoch: 3 || example: 7
# 0
# 0
# 0.6305792927742004
# Epoch: 3 || example: 8
# 1
# 0
# 0.7715443968772888
# Epoch: 3 || example: 9
# 1
# 0
# 0.7763113975524902
# Epoch: 3 || example: 10
# 0
# 0
# 0.6176769733428955
# Epoch: 3 || example: 11
# 1
# 0
# 0.7783803939819336
# Epoch: 3 || example: 12
# 1
# 0
# 0.775776743888855
# Epoch: 3 || example: 13
# 0
# 0
# 0.6238208413124084
# Epoch: 3 || example: 14
# 0
# 0
# 0.6258352398872375
# Epoch: 3 || example: 15
# 1
# 0
# 0.7682119011878967
# Epoch: 3 || example: 16
# 0
# 0
# 0.6260489225387573
# Epoch: 3 || example: 17
# 1
# 0
# 0.7672308683395386
# Epoch: 3 || example: 18
# 1
# 0
# 0.7634409666061401
# Epoch: 3 || example: 19
# 1
# 0
# 0.7543699741363525
# Epoch: 3 || example: 20
# 1
# 0
# 0.7407110929489136
# Epoch: 3 || example: 21
# 0
# 0
# 0.6640079021453857
# Epoch: 3 || example: 22
# 1
# 0
# 0.712543785572052
# Epoch: 3 || example: 23
# 0
# 0
# 0.6883706450462341
# Epoch: 3 || example: 24
# 0
# 1
# 0.6963698863983154
# Epoch: 3 || example: 25
# 0
# 1
# 0.6985683441162109
# Epoch: 3 || example: 26
# 0
# 1
# 0.6954995393753052
# Epoch: 3 || example: 27
# 1
# 0
# 0.6985753178596497
# Epoch: 3 || example: 28
# 1
# 0
# 0.700547456741333
# Epoch: 3 || example: 29
# 0
# 0
# 0.6890556812286377
# Epoch: 3 || example: 30
# 1
# 0
# 0.6992995142936707
# Epoch: 3 || example: 31
# 0
# 0
# 0.6902183294296265
# Epoch: 3 || example: 32
# 1
# 0
# 0.6981979608535767
# Epoch: 3 || example: 33
# 0
# 0
# 0.6912416219711304
# Epoch: 3 || example: 34
# 1
# 0
# 0.6972357630729675
# Epoch: 3 || example: 35
# 0
# 0
# 0.692132294178009
# Epoch: 3 || example: 36
# 0
# 0
# 0.6899005174636841
# Epoch: 3 || example: 37
# 0
# 0
# 0.6829510927200317
# Epoch: 3 || example: 38
# 0
# 0
# 0.6718838214874268
# Epoch: 3 || example: 39
# 0
# 0
# 0.6573054194450378
# Epoch: 3 || example: 40
# 0
# 0
# 0.6398121118545532
# Epoch: 3 || example: 41
# 0
# 0
# 0.6199761629104614
# Epoch: 3 || example: 42
# 1
# 0
# 0.7978991270065308
# Epoch: 3 || example: 43
# 1
# 0
# 0.8154516220092773
# Epoch: 3 || example: 44
# 1
# 0
# 0.8251802921295166
# Epoch: 3 || example: 45
# 1
# 0
# 0.8276586532592773
# Epoch: 3 || example: 46
# 0
# 0
# 0.5777963399887085
# Epoch: 3 || example: 47
# 0
# 0
# 0.5768252015113831
# Epoch: 3 || example: 48
# 1
# 0
# 0.8308606147766113
# Epoch: 3 || example: 49
# 1
# 0
# 0.8299560546875
# Epoch: 3 || example: 50
# 1
# 0
# 0.8228018879890442
# Epoch: 3 || example: 51
# 1
# 0
# 0.810154378414154
# Epoch: 3 || example: 52
# 1
# 0
# 0.7927863001823425
# Epoch: 3 || example: 53
# 1
# 0
# 0.7714636921882629
# Epoch: 3 || example: 54
# 0
# 0
# 0.6421108245849609
# Epoch: 3 || example: 55
# 1
# 0
# 0.7302005887031555
# Epoch: 3 || example: 56
# 1
# 0
# 0.7100816965103149
# Epoch: 3 || example: 57
# 1
# 1
# 0.6872361898422241
# Epoch: 3 || example: 58
# 0
# 1
# 0.7249871492385864
# Epoch: 3 || example: 59
# 1
# 1
# 0.6452804803848267
# Epoch: 3 || example: 60
# 0
# 1
# 0.765353798866272
# Epoch: 3 || example: 61
# 1
# 1
# 0.6135329604148865
# Epoch: 3 || example: 62
# 1
# 1
# 0.5984969735145569
# Epoch: 3 || example: 63
# 0
# 1
# 0.8192046880722046
# Epoch: 3 || example: 64
# 0
# 1
# 0.8325390815734863
# Epoch: 3 || example: 65
# 0
# 1
# 0.8382291793823242
# Epoch: 3 || example: 66
# 0
# 1
# 0.8369202613830566
# Epoch: 3 || example: 67
# 1
# 1
# 0.5733019709587097
# Epoch: 3 || example: 68
# 0
# 1
# 0.8274507522583008
# Epoch: 3 || example: 69
# 1
# 1
# 0.5810271501541138
# Epoch: 3 || example: 70
# 1
# 1
# 0.5828046202659607
# Epoch: 3 || example: 71
# 0
# 1
# 0.820103645324707
# Epoch: 3 || example: 72
# 0
# 1
# 0.8164681196212769
# Epoch: 3 || example: 73
# 0
# 1
# 0.807009220123291
# Epoch: 3 || example: 74
# 1
# 1
# 0.6027956604957581
# Epoch: 3 || example: 75
# 0
# 1
# 0.7844638824462891
# Epoch: 3 || example: 76
# 0
# 1
# 0.7714345455169678
# Epoch: 3 || example: 77
# 0
# 1
# 0.7541226744651794
# Epoch: 3 || example: 78
# 0
# 1
# 0.7332481145858765
# Epoch: 3 || example: 79
# 1
# 1
# 0.6770530343055725
# Epoch: 3 || example: 80
# 0
# 1
# 0.6935001611709595
# Epoch: 3 || example: 81
# 1
# 0
# 0.7122609615325928
# Epoch: 3 || example: 82
# 1
# 0
# 0.72483229637146
# Epoch: 3 || example: 83
# 1
# 0
# 0.7309147119522095
# Epoch: 3 || example: 84
# 1
# 0
# 0.7310268878936768
# Epoch: 3 || example: 85
# 0
# 0
# 0.6615623831748962
# Epoch: 3 || example: 86
# 1
# 0
# 0.7260304093360901
# Epoch: 3 || example: 87
# 0
# 0
# 0.6660914421081543
# Epoch: 3 || example: 88
# 1
# 0
# 0.7213950753211975
# Epoch: 3 || example: 89
# 1
# 0
# 0.7165197134017944
# Epoch: 3 || example: 90
# 1
# 0
# 0.7069523930549622
# Epoch: 3 || example: 91
# 1
# 0
# 0.6933350563049316
# Epoch: 3 || example: 92
# 0
# 1
# 0.7102755308151245
# Epoch: 3 || example: 93
# 0
# 1
# 0.7208752632141113
# Epoch: 3 || example: 94
# 1
# 1
# 0.6620945930480957
# Epoch: 3 || example: 95
# 0
# 1
# 0.7341228127479553
# Epoch: 3 || example: 96
# 0
# 1
# 0.7367849349975586
# Epoch: 3 || example: 97
# 0
# 1
# 0.7337518930435181
# Epoch: 3 || example: 98
# 0
# 1
# 0.7256507277488708
# Epoch: 3 || example: 99
# 1
# 1
# 0.6735495924949646
# Epoch: 3 || example: 100
# 0
# 1
# 0.706957221031189
# Epoch: 3 || example: 101
# 1
# 1
# 0.6899746060371399
# Epoch: 3 || example: 102
# 0
# 0
# 0.691825270652771
# Epoch: 3 || example: 103
# 1
# 0
# 0.7035674452781677
# Epoch: 3 || example: 104
# 0
# 0
# 0.6797836422920227
# Epoch: 3 || example: 105
# 1
# 0
# 0.714536726474762
# Epoch: 3 || example: 106
# 0
# 0
# 0.6704115867614746
# Epoch: 3 || example: 107
# 1
# 0
# 0.7231194972991943
# Epoch: 3 || example: 108
# 1
# 0
# 0.723876416683197
# Epoch: 3 || example: 109
# 1
# 0
# 0.7192606329917908
# Epoch: 3 || example: 110
# 1
# 0
# 0.709896445274353
# Epoch: 3 || example: 111
# 1
# 0
# 0.6964280009269714
# Epoch: 3 || example: 112
# 1
# 1
# 0.6794984340667725
# Epoch: 3 || example: 113
# 0
# 1
# 0.7277160882949829
# Epoch: 3 || example: 114
# 1
# 1
# 0.6472086906433105
# Epoch: 3 || example: 115
# 1
# 1
# 0.6316079497337341
# Epoch: 3 || example: 116
# 1
# 1
# 0.6134941577911377
# Epoch: 3 || example: 117
# 0
# 1
# 0.8039559721946716
# Epoch: 3 || example: 118
# 1
# 1
# 0.5805847644805908
# Epoch: 3 || example: 119
# 1
# 1
# 0.5654117465019226
# Epoch: 3 || example: 120
# 0
# 1
# 0.8625123500823975
# Epoch: 3 || example: 121
# 0
# 1
# 0.8766824007034302
# Epoch: 3 || example: 122
# 0
# 1
# 0.8826960325241089
# Epoch: 3 || example: 123
# 0
# 1
# 0.8812448978424072
# Epoch: 3 || example: 124
# 1
# 1
# 0.5406907796859741
# Epoch: 3 || example: 125
# 0
# 1
# 0.8706601858139038
# Epoch: 3 || example: 126
# 0
# 1
# 0.8617351055145264
# Epoch: 3 || example: 127
# 0
# 1
# 0.847135603427887
# Epoch: 3 || example: 128
# 0
# 1
# 0.8276824951171875
# Epoch: 3 || example: 129
# 0
# 1
# 0.8041855096817017
# Epoch: 3 || example: 130
# 0
# 1
# 0.7774258852005005
# Epoch: 3 || example: 131
# 0
# 1
# 0.7481435537338257
# Epoch: 3 || example: 132
# 1
# 1
# 0.6698258519172668
# Epoch: 3 || example: 133
# 0
# 1
# 0.6946637034416199
# Epoch: 3 || example: 134
# 0
# 0
# 0.6700519919395447
# Epoch: 3 || example: 135
# 1
# 0
# 0.7450757622718811
# Epoch: 3 || example: 136
# 1
# 0
# 0.7655354142189026
# Epoch: 3 || example: 137
# 1
# 0
# 0.7784650921821594
# Epoch: 3 || example: 138
# 1
# 0
# 0.7843297719955444
# Epoch: 3 || example: 139
# 0
# 0
# 0.6101077795028687
# Epoch: 3 || example: 140
# 0
# 0
# 0.6064118146896362
# Epoch: 3 || example: 141
# 1
# 0
# 0.7970989942550659
# Epoch: 3 || example: 142
# 0
# 0
# 0.5972954034805298
# Epoch: 3 || example: 143
# 1
# 0
# 0.8060040473937988
# Epoch: 3 || example: 144
# 0
# 0
# 0.5917100310325623
# Epoch: 3 || example: 145
# 0
# 0
# 0.5876992344856262
# Epoch: 3 || example: 146
# 0
# 0
# 0.5801841616630554
# Epoch: 3 || example: 147
# 0
# 0
# 0.5696486234664917
# Epoch: 3 || example: 148
# 1
# 0
# 0.8513705730438232
# Epoch: 3 || example: 149
# 0
# 0
# 0.5498286485671997
# Epoch: 3 || example: 150
# 1
# 0
# 0.8736850619316101
# Epoch: 3 || example: 151
# 1
# 0
# 0.8788310885429382
# Epoch: 3 || example: 152
# 1
# 0
# 0.8766345381736755
# Epoch: 3 || example: 153
# 0
# 0
# 0.5444598197937012
# Epoch: 3 || example: 154
# 1
# 0
# 0.8648812174797058
# Epoch: 3 || example: 155
# 1
# 0
# 0.8555240631103516
# Epoch: 3 || example: 156
# 0
# 0
# 0.5646659731864929
# Epoch: 3 || example: 157
# 0
# 0
# 0.5711033344268799
# Epoch: 3 || example: 158
# 1
# 0
# 0.8295482397079468
# Epoch: 3 || example: 159
# 1
# 0
# 0.8208519816398621
# Epoch: 3 || example: 160
# 1
# 0
# 0.8068591356277466
# Epoch: 3 || example: 161
# 1
# 0
# 0.7883433699607849
# Epoch: 3 || example: 162
# 1
# 0
# 0.7660675048828125
# Epoch: 3 || example: 163
# 0
# 0
# 0.6476932764053345
# Epoch: 3 || example: 164
# 1
# 0
# 0.7233800292015076
# Epoch: 3 || example: 165
# 0
# 0
# 0.6836249828338623
# Epoch: 3 || example: 166
# 1
# 1
# 0.6894749402999878
# Epoch: 3 || example: 167
# 0
# 1
# 0.7139419317245483
# Epoch: 3 || example: 168
# 0
# 1
# 0.7243116497993469
# Epoch: 3 || example: 169
# 1
# 1
# 0.6591073870658875
# Epoch: 3 || example: 170
# 1
# 1
# 0.6510541439056396
# Epoch: 3 || example: 171
# 0
# 1
# 0.7500214576721191
# Epoch: 3 || example: 172
# 0
# 1
# 0.7561764717102051
# Epoch: 3 || example: 173
# 1
# 1
# 0.6339223384857178
# Epoch: 3 || example: 174
# 0
# 1
# 0.7610265016555786
# Epoch: 3 || example: 175
# 0
# 1
# 0.7597912549972534
# Epoch: 3 || example: 176
# 1
# 1
# 0.6366443634033203
# Epoch: 3 || example: 177
# 0
# 1
# 0.7519557476043701
# Epoch: 3 || example: 178
# 1
# 1
# 0.6434744000434875
# Epoch: 3 || example: 179
# 1
# 1
# 0.6442700624465942
# Epoch: 3 || example: 180
# 1
# 1
# 0.6404828429222107
# Epoch: 3 || example: 181
# 0
# 1
# 0.7575502395629883
# Epoch: 3 || example: 182
# 0
# 1
# 0.7598695755004883
# Epoch: 3 || example: 183
# 0
# 1
# 0.7562985420227051
# Epoch: 3 || example: 184
# 1
# 1
# 0.6416027545928955
# Epoch: 3 || example: 185
# 1
# 1
# 0.6442217826843262
# Epoch: 3 || example: 186
# 1
# 1
# 0.6420737504959106
# Epoch: 3 || example: 187
# 0
# 1
# 0.7541237473487854
# Epoch: 3 || example: 188
# 0
# 1
# 0.7549738883972168
# Epoch: 3 || example: 189
# 0
# 1
# 0.7501322627067566
# Epoch: 3 || example: 190
# 0
# 1
# 0.7402589321136475
# Epoch: 3 || example: 191
# 0
# 1
# 0.7260352373123169
# Epoch: 3 || example: 192
# 1
# 1
# 0.6783738136291504
# Epoch: 3 || example: 193
# 1
# 1
# 0.6890780329704285
# Epoch: 3 || example: 194
# 0
# 0
# 0.6924784183502197
# Epoch: 3 || example: 195
# 1
# 0
# 0.7031338810920715
# Epoch: 3 || example: 196
# 0
# 0
# 0.6800054311752319
# Epoch: 3 || example: 197
# 1
# 0
# 0.7144961357116699
# Epoch: 3 || example: 198
# 1
# 0
# 0.7165417075157166
# Epoch: 3 || example: 199
# 1
# 0
# 0.7131561040878296
# Epoch: 3 || example: 200
# 0
# 0
# 0.6814854145050049
# Epoch: 4 || example: 0
# 0
# 0
# 0.6837931871414185
# Epoch: 4 || example: 1
# 0
# 0
# 0.6809703707695007
# Epoch: 4 || example: 2
# 0
# 0
# 0.6735833883285522
# Epoch: 4 || example: 3
# 0
# 0
# 0.6622239351272583
# Epoch: 4 || example: 4
# 1
# 0
# 0.7409910559654236
# Epoch: 4 || example: 5
# 1
# 0
# 0.749995768070221
# Epoch: 4 || example: 6
# 0
# 0
# 0.6370601654052734
# Epoch: 4 || example: 7
# 0
# 0
# 0.6305792927742004
# Epoch: 4 || example: 8
# 1
# 0
# 0.7715443968772888
# Epoch: 4 || example: 9
# 1
# 0
# 0.7763113975524902
# Epoch: 4 || example: 10
# 0
# 0
# 0.6176769733428955
# Epoch: 4 || example: 11
# 1
# 0
# 0.7783803939819336
# Epoch: 4 || example: 12
# 1
# 0
# 0.775776743888855
# Epoch: 4 || example: 13
# 0
# 0
# 0.6238208413124084
# Epoch: 4 || example: 14
# 0
# 0
# 0.6258352398872375
# Epoch: 4 || example: 15
# 1
# 0
# 0.7682119011878967
# Epoch: 4 || example: 16
# 0
# 0
# 0.6260489225387573
# Epoch: 4 || example: 17
# 1
# 0
# 0.7672308683395386
# Epoch: 4 || example: 18
# 1
# 0
# 0.7634409666061401
# Epoch: 4 || example: 19
# 1
# 0
# 0.7543699741363525
# Epoch: 4 || example: 20
# 1
# 0
# 0.7407110929489136
# Epoch: 4 || example: 21
# 0
# 0
# 0.6640079021453857
# Epoch: 4 || example: 22
# 1
# 0
# 0.712543785572052
# Epoch: 4 || example: 23
# 0
# 0
# 0.6883706450462341
# Epoch: 4 || example: 24
# 0
# 1
# 0.6963698863983154
# Epoch: 4 || example: 25
# 0
# 1
# 0.6985683441162109
# Epoch: 4 || example: 26
# 0
# 1
# 0.6954995393753052
# Epoch: 4 || example: 27
# 1
# 0
# 0.6985753178596497
# Epoch: 4 || example: 28
# 1
# 0
# 0.700547456741333
# Epoch: 4 || example: 29
# 0
# 0
# 0.6890556812286377
# Epoch: 4 || example: 30
# 1
# 0
# 0.6992995142936707
# Epoch: 4 || example: 31
# 0
# 0
# 0.6902183294296265
# Epoch: 4 || example: 32
# 1
# 0
# 0.6981979608535767
# Epoch: 4 || example: 33
# 0
# 0
# 0.6912416219711304
# Epoch: 4 || example: 34
# 1
# 0
# 0.6972357630729675
# Epoch: 4 || example: 35
# 0
# 0
# 0.692132294178009
# Epoch: 4 || example: 36
# 0
# 0
# 0.6899005174636841
# Epoch: 4 || example: 37
# 0
# 0
# 0.6829510927200317
# Epoch: 4 || example: 38
# 0
# 0
# 0.6718838214874268
# Epoch: 4 || example: 39
# 0
# 0
# 0.6573054194450378
# Epoch: 4 || example: 40
# 0
# 0
# 0.6398121118545532
# Epoch: 4 || example: 41
# 0
# 0
# 0.6199761629104614
# Epoch: 4 || example: 42
# 1
# 0
# 0.7978991270065308
# Epoch: 4 || example: 43
# 1
# 0
# 0.8154516220092773
# Epoch: 4 || example: 44
# 1
# 0
# 0.8251802921295166
# Epoch: 4 || example: 45
# 1
# 0
# 0.8276586532592773
# Epoch: 4 || example: 46
# 0
# 0
# 0.5777963399887085
# Epoch: 4 || example: 47
# 0
# 0
# 0.5768252015113831
# Epoch: 4 || example: 48
# 1
# 0
# 0.8308606147766113
# Epoch: 4 || example: 49
# 1
# 0
# 0.8299560546875
# Epoch: 4 || example: 50
# 1
# 0
# 0.8228018879890442
# Epoch: 4 || example: 51
# 1
# 0
# 0.810154378414154
# Epoch: 4 || example: 52
# 1
# 0
# 0.7927863001823425
# Epoch: 4 || example: 53
# 1
# 0
# 0.7714636921882629
# Epoch: 4 || example: 54
# 0
# 0
# 0.6421108245849609
# Epoch: 4 || example: 55
# 1
# 0
# 0.7302005887031555
# Epoch: 4 || example: 56
# 1
# 0
# 0.7100816965103149
# Epoch: 4 || example: 57
# 1
# 1
# 0.6872361898422241
# Epoch: 4 || example: 58
# 0
# 1
# 0.7249871492385864
# Epoch: 4 || example: 59
# 1
# 1
# 0.6452804803848267
# Epoch: 4 || example: 60
# 0
# 1
# 0.765353798866272
# Epoch: 4 || example: 61
# 1
# 1
# 0.6135329604148865
# Epoch: 4 || example: 62
# 1
# 1
# 0.5984969735145569
# Epoch: 4 || example: 63
# 0
# 1
# 0.8192046880722046
# Epoch: 4 || example: 64
# 0
# 1
# 0.8325390815734863
# Epoch: 4 || example: 65
# 0
# 1
# 0.8382291793823242
# Epoch: 4 || example: 66
# 0
# 1
# 0.8369202613830566
# Epoch: 4 || example: 67
# 1
# 1
# 0.5733019709587097
# Epoch: 4 || example: 68
# 0
# 1
# 0.8274507522583008
# Epoch: 4 || example: 69
# 1
# 1
# 0.5810271501541138
# Epoch: 4 || example: 70
# 1
# 1
# 0.5828046202659607
# Epoch: 4 || example: 71
# 0
# 1
# 0.820103645324707
# Epoch: 4 || example: 72
# 0
# 1
# 0.8164681196212769
# Epoch: 4 || example: 73
# 0
# 1
# 0.807009220123291
# Epoch: 4 || example: 74
# 1
# 1
# 0.6027956604957581
# Epoch: 4 || example: 75
# 0
# 1
# 0.7844638824462891
# Epoch: 4 || example: 76
# 0
# 1
# 0.7714345455169678
# Epoch: 4 || example: 77
# 0
# 1
# 0.7541226744651794
# Epoch: 4 || example: 78
# 0
# 1
# 0.7332481145858765
# Epoch: 4 || example: 79
# 1
# 1
# 0.6770530343055725
# Epoch: 4 || example: 80
# 0
# 1
# 0.6935001611709595
# Epoch: 4 || example: 81
# 1
# 0
# 0.7122609615325928
# Epoch: 4 || example: 82
# 1
# 0
# 0.72483229637146
# Epoch: 4 || example: 83
# 1
# 0
# 0.7309147119522095
# Epoch: 4 || example: 84
# 1
# 0
# 0.7310268878936768
# Epoch: 4 || example: 85
# 0
# 0
# 0.6615623831748962
# Epoch: 4 || example: 86
# 1
# 0
# 0.7260304093360901
# Epoch: 4 || example: 87
# 0
# 0
# 0.6660914421081543
# Epoch: 4 || example: 88
# 1
# 0
# 0.7213950753211975
# Epoch: 4 || example: 89
# 1
# 0
# 0.7165197134017944
# Epoch: 4 || example: 90
# 1
# 0
# 0.7069523930549622
# Epoch: 4 || example: 91
# 1
# 0
# 0.6933350563049316
# Epoch: 4 || example: 92
# 0
# 1
# 0.7102755308151245
# Epoch: 4 || example: 93
# 0
# 1
# 0.7208752632141113
# Epoch: 4 || example: 94
# 1
# 1
# 0.6620945930480957
# Epoch: 4 || example: 95
# 0
# 1
# 0.7341228127479553
# Epoch: 4 || example: 96
# 0
# 1
# 0.7367849349975586
# Epoch: 4 || example: 97
# 0
# 1
# 0.7337518930435181
# Epoch: 4 || example: 98
# 0
# 1
# 0.7256507277488708
# Epoch: 4 || example: 99
# 1
# 1
# 0.6735495924949646
# Epoch: 4 || example: 100
# 0
# 1
# 0.706957221031189
# Epoch: 4 || example: 101
# 1
# 1
# 0.6899746060371399
# Epoch: 4 || example: 102
# 0
# 0
# 0.691825270652771
# Epoch: 4 || example: 103
# 1
# 0
# 0.7035674452781677
# Epoch: 4 || example: 104
# 0
# 0
# 0.6797836422920227
# Epoch: 4 || example: 105
# 1
# 0
# 0.714536726474762
# Epoch: 4 || example: 106
# 0
# 0
# 0.6704115867614746
# Epoch: 4 || example: 107
# 1
# 0
# 0.7231194972991943
# Epoch: 4 || example: 108
# 1
# 0
# 0.723876416683197
# Epoch: 4 || example: 109
# 1
# 0
# 0.7192606329917908
# Epoch: 4 || example: 110
# 1
# 0
# 0.709896445274353
# Epoch: 4 || example: 111
# 1
# 0
# 0.6964280009269714
# Epoch: 4 || example: 112
# 1
# 1
# 0.6794984340667725
# Epoch: 4 || example: 113
# 0
# 1
# 0.7277160882949829
# Epoch: 4 || example: 114
# 1
# 1
# 0.6472086906433105
# Epoch: 4 || example: 115
# 1
# 1
# 0.6316079497337341
# Epoch: 4 || example: 116
# 1
# 1
# 0.6134941577911377
# Epoch: 4 || example: 117
# 0
# 1
# 0.8039559721946716
# Epoch: 4 || example: 118
# 1
# 1
# 0.5805847644805908
# Epoch: 4 || example: 119
# 1
# 1
# 0.5654117465019226
# Epoch: 4 || example: 120
# 0
# 1
# 0.8625123500823975
# Epoch: 4 || example: 121
# 0
# 1
# 0.8766824007034302
# Epoch: 4 || example: 122
# 0
# 1
# 0.8826960325241089
# Epoch: 4 || example: 123
# 0
# 1
# 0.8812448978424072
# Epoch: 4 || example: 124
# 1
# 1
# 0.5406907796859741
# Epoch: 4 || example: 125
# 0
# 1
# 0.8706601858139038
# Epoch: 4 || example: 126
# 0
# 1
# 0.8617351055145264
# Epoch: 4 || example: 127
# 0
# 1
# 0.847135603427887
# Epoch: 4 || example: 128
# 0
# 1
# 0.8276824951171875
# Epoch: 4 || example: 129
# 0
# 1
# 0.8041855096817017
# Epoch: 4 || example: 130
# 0
# 1
# 0.7774258852005005
# Epoch: 4 || example: 131
# 0
# 1
# 0.7481435537338257
# Epoch: 4 || example: 132
# 1
# 1
# 0.6698258519172668
# Epoch: 4 || example: 133
# 0
# 1
# 0.6946637034416199
# Epoch: 4 || example: 134
# 0
# 0
# 0.6700519919395447
# Epoch: 4 || example: 135
# 1
# 0
# 0.7450757622718811
# Epoch: 4 || example: 136
# 1
# 0
# 0.7655354142189026
# Epoch: 4 || example: 137
# 1
# 0
# 0.7784650921821594
# Epoch: 4 || example: 138
# 1
# 0
# 0.7843297719955444
# Epoch: 4 || example: 139
# 0
# 0
# 0.6101077795028687
# Epoch: 4 || example: 140
# 0
# 0
# 0.6064118146896362
# Epoch: 4 || example: 141
# 1
# 0
# 0.7970989942550659
# Epoch: 4 || example: 142
# 0
# 0
# 0.5972954034805298
# Epoch: 4 || example: 143
# 1
# 0
# 0.8060040473937988
# Epoch: 4 || example: 144
# 0
# 0
# 0.5917100310325623
# Epoch: 4 || example: 145
# 0
# 0
# 0.5876992344856262
# Epoch: 4 || example: 146
# 0
# 0
# 0.5801841616630554
# Epoch: 4 || example: 147
# 0
# 0
# 0.5696486234664917
# Epoch: 4 || example: 148
# 1
# 0
# 0.8513705730438232
# Epoch: 4 || example: 149
# 0
# 0
# 0.5498286485671997
# Epoch: 4 || example: 150
# 1
# 0
# 0.8736850619316101
# Epoch: 4 || example: 151
# 1
# 0
# 0.8788310885429382
# Epoch: 4 || example: 152
# 1
# 0
# 0.8766345381736755
# Epoch: 4 || example: 153
# 0
# 0
# 0.5444598197937012
# Epoch: 4 || example: 154
# 1
# 0
# 0.8648812174797058
# Epoch: 4 || example: 155
# 1
# 0
# 0.8555240631103516
# Epoch: 4 || example: 156
# 0
# 0
# 0.5646659731864929
# Epoch: 4 || example: 157
# 0
# 0
# 0.5711033344268799
# Epoch: 4 || example: 158
# 1
# 0
# 0.8295482397079468
# Epoch: 4 || example: 159
# 1
# 0
# 0.8208519816398621
# Epoch: 4 || example: 160
# 1
# 0
# 0.8068591356277466
# Epoch: 4 || example: 161
# 1
# 0
# 0.7883433699607849
# Epoch: 4 || example: 162
# 1
# 0
# 0.7660675048828125
# Epoch: 4 || example: 163
# 0
# 0
# 0.6476932764053345
# Epoch: 4 || example: 164
# 1
# 0
# 0.7233800292015076
# Epoch: 4 || example: 165
# 0
# 0
# 0.6836249828338623
# Epoch: 4 || example: 166
# 1
# 1
# 0.6894749402999878
# Epoch: 4 || example: 167
# 0
# 1
# 0.7139419317245483
# Epoch: 4 || example: 168
# 0
# 1
# 0.7243116497993469
# Epoch: 4 || example: 169
# 1
# 1
# 0.6591073870658875
# Epoch: 4 || example: 170
# 1
# 1
# 0.6510541439056396
# Epoch: 4 || example: 171
# 0
# 1
# 0.7500214576721191
# Epoch: 4 || example: 172
# 0
# 1
# 0.7561764717102051
# Epoch: 4 || example: 173
# 1
# 1
# 0.6339223384857178
# Epoch: 4 || example: 174
# 0
# 1
# 0.7610265016555786
# Epoch: 4 || example: 175
# 0
# 1
# 0.7597912549972534
# Epoch: 4 || example: 176
# 1
# 1
# 0.6366443634033203
# Epoch: 4 || example: 177
# 0
# 1
# 0.7519557476043701
# Epoch: 4 || example: 178
# 1
# 1
# 0.6434744000434875
# Epoch: 4 || example: 179
# 1
# 1
# 0.6442700624465942
# Epoch: 4 || example: 180
# 1
# 1
# 0.6404828429222107
# Epoch: 4 || example: 181
# 0
# 1
# 0.7575502395629883
# Epoch: 4 || example: 182
# 0
# 1
# 0.7598695755004883
# Epoch: 4 || example: 183
# 0
# 1
# 0.7562985420227051
# Epoch: 4 || example: 184
# 1
# 1
# 0.6416027545928955
# Epoch: 4 || example: 185
# 1
# 1
# 0.6442217826843262
# Epoch: 4 || example: 186
# 1
# 1
# 0.6420737504959106
# Epoch: 4 || example: 187
# 0
# 1
# 0.7541237473487854
# Epoch: 4 || example: 188
# 0
# 1
# 0.7549738883972168
# Epoch: 4 || example: 189
# 0
# 1
# 0.7501322627067566
# Epoch: 4 || example: 190
# 0
# 1
# 0.7402589321136475
# Epoch: 4 || example: 191
# 0
# 1
# 0.7260352373123169
# Epoch: 4 || example: 192
# 1
# 1
# 0.6783738136291504
# Epoch: 4 || example: 193
# 1
# 1
# 0.6890780329704285
# Epoch: 4 || example: 194
# 0
# 0
# 0.6924784183502197
# Epoch: 4 || example: 195
# 1
# 0
# 0.7031338810920715
# Epoch: 4 || example: 196
# 0
# 0
# 0.6800054311752319
# Epoch: 4 || example: 197
# 1
# 0
# 0.7144961357116699
# Epoch: 4 || example: 198
# 1
# 0
# 0.7165417075157166
# Epoch: 4 || example: 199
# 1
# 0
# 0.7131561040878296
# Epoch: 4 || example: 200
# 0
# 0
# 0.6814854145050049
# Epoch: 5 || example: 0
# 0
# 0
# 0.6837931871414185
# Epoch: 5 || example: 1
# 0
# 0
# 0.6809703707695007
# Epoch: 5 || example: 2
# 0
# 0
# 0.6735833883285522
# Epoch: 5 || example: 3
# 0
# 0
# 0.6622239351272583
# Epoch: 5 || example: 4
# 1
# 0
# 0.7409910559654236
# Epoch: 5 || example: 5
# 1
# 0
# 0.749995768070221
# Epoch: 5 || example: 6
# 0
# 0
# 0.6370601654052734
# Epoch: 5 || example: 7
# 0
# 0
# 0.6305792927742004
# Epoch: 5 || example: 8
# 1
# 0
# ...
# 1
# 0.8625123500823975
# Epoch: 13 || example: 121
# 0
# 1
# 0.8766824007034302
# Epoch: 13 || example: 122
# 0
# 1
# 0.8826960325241089
# Epoch: 13 || example: 123
# 0
# 1
# 0.8812448978424072
# Epoch: 13 || example: 124
# 1
# 1
# 0.5406907796859741
# Epoch: 13 || example: 125
# 0
# 1
# 0.8706601858139038
# Epoch: 13 || example: 126
# 0
# 1
# 0.8617351055145264
# Epoch: 13 || example: 127
# 0
# 1
# 0.847135603427887
# Epoch: 13 || example: 128
# 0
# 1
# 0.8276824951171875
# Epoch: 13 || example: 129
# 0
# 1
# 0.8041855096817017
# Epoch: 13 || example: 130
# 0
# 1
# 0.7774258852005005
# Epoch: 13 || example: 131
# 0
# 1
# 0.7481435537338257
# Epoch: 13 || example: 132
# 1
# 1
# 0.6698258519172668
# Epoch: 13 || example: 133
# 0
# 1
# 0.6946637034416199
# Epoch: 13 || example: 134
# 0
# 0
# 0.6700519919395447
# Epoch: 13 || example: 135
# 1
# 0
# 0.7450757622718811
# Epoch: 13 || example: 136
# 1
# 0
# 0.7655354142189026
# Epoch: 13 || example: 137
# 1
# 0
# 0.7784650921821594
# Epoch: 13 || example: 138
# 1
# 0
# 0.7843297719955444
# Epoch: 13 || example: 139
# 0
# 0
# 0.6101077795028687
# Epoch: 13 || example: 140
# 0
# 0
# 0.6064118146896362
# Epoch: 13 || example: 141
# 1
# 0
# 0.7970989942550659
# Epoch: 13 || example: 142
# 0
# 0
# 0.5972954034805298
# Epoch: 13 || example: 143
# 1
# 0
# 0.8060040473937988
# Epoch: 13 || example: 144
# 0
# 0
# 0.5917100310325623
# Epoch: 13 || example: 145
# 0
# 0
# 0.5876992344856262
# Epoch: 13 || example: 146
# 0
# 0
# 0.5801841616630554
# Epoch: 13 || example: 147
# 0
# 0
# 0.5696486234664917
# Epoch: 13 || example: 148
# 1
# 0
# 0.8513705730438232
# Epoch: 13 || example: 149
# 0
# 0
# 0.5498286485671997
# Epoch: 13 || example: 150
# 1
# 0
# 0.8736850619316101
# Epoch: 13 || example: 151
# 1
# 0
# 0.8788310885429382
# Epoch: 13 || example: 152
# 1
# 0
# 0.8766345381736755
# Epoch: 13 || example: 153
# 0
# 0
# 0.5444598197937012
# Epoch: 13 || example: 154
# 1
# 0
# 0.8648812174797058
# Epoch: 13 || example: 155
# 1
# 0
# 0.8555240631103516
# Epoch: 13 || example: 156
# 0
# 0
# 0.5646659731864929
# Epoch: 13 || example: 157
# 0
# 0
# 0.5711033344268799
# Epoch: 13 || example: 158
# 1
# 0
# 0.8295482397079468
# Epoch: 13 || example: 159
# 1
# 0
# 0.8208519816398621
# Epoch: 13 || example: 160
# 1
# 0
# 0.8068591356277466
# Epoch: 13 || example: 161
# 1
# 0
# 0.7883433699607849
# Epoch: 13 || example: 162
# 1
# 0
# 0.7660675048828125
# Epoch: 13 || example: 163
# 0
# 0
# 0.6476932764053345
# Epoch: 13 || example: 164
# 1
# 0
# 0.7233800292015076
# Epoch: 13 || example: 165
# 0
# 0
# 0.6836249828338623
# Epoch: 13 || example: 166
# 1
# 1
# 0.6894749402999878
# Epoch: 13 || example: 167
# 0
# 1
# 0.7139419317245483
# Epoch: 13 || example: 168
# 0
# 1
# 0.7243116497993469
# Epoch: 13 || example: 169
# 1
# 1
# 0.6591073870658875
# Epoch: 13 || example: 170
# 1
# 1
# 0.6510541439056396
# Epoch: 13 || example: 171
# 0
# 1
# 0.7500214576721191
# Epoch: 13 || example: 172
# 0
# 1
# 0.7561764717102051
# Epoch: 13 || example: 173
# 1
# 1
# 0.6339223384857178
# Epoch: 13 || example: 174
# 0
# 1
# 0.7610265016555786
# Epoch: 13 || example: 175
# 0
# 1
# 0.7597912549972534
# Epoch: 13 || example: 176
# 1
# 1
# 0.6366443634033203
# Epoch: 13 || example: 177
# 0
# 1
# 0.7519557476043701
# Epoch: 13 || example: 178
# 1
# 1
# 0.6434744000434875
# Epoch: 13 || example: 179
# 1
# 1
# 0.6442700624465942
# Epoch: 13 || example: 180
# 1
# 1
# 0.6404828429222107
# Epoch: 13 || example: 181
# 0
# 1
# 0.7575502395629883
# Epoch: 13 || example: 182
# 0
# 1
# 0.7598695755004883
# Epoch: 13 || example: 183
# 0
# 1
# 0.7562985420227051
# Epoch: 13 || example: 184
# 1
# 1
# 0.6416027545928955
# Epoch: 13 || example: 185
# 1
# 1
# 0.6442217826843262
# Epoch: 13 || example: 186
# 1
# 1
# 0.6420737504959106
# Epoch: 13 || example: 187
# 0
# 1
# 0.7541237473487854
# Epoch: 13 || example: 188
# 0
# 1
# 0.7549738883972168
# Epoch: 13 || example: 189
# 0
# 1
# 0.7501322627067566
# Epoch: 13 || example: 190
# 0
# 1
# 0.7402589321136475
# Epoch: 13 || example: 191
# 0
# 1
# 0.7260352373123169
# Epoch: 13 || example: 192
# 1
# 1
# 0.6783738136291504
# Epoch: 13 || example: 193
# 1
# 1
# 0.6890780329704285
# Epoch: 13 || example: 194
# 0
# 0
# 0.6924784183502197
# Epoch: 13 || example: 195
# 1
# 0
# 0.7031338810920715
# Epoch: 13 || example: 196
# 0
# 0
# 0.6800054311752319
# Epoch: 13 || example: 197
# 1
# 0
# 0.7144961357116699
# Epoch: 13 || example: 198
# 1
# 0
# 0.7165417075157166
# Epoch: 13 || example: 199
# 1
# 0
# 0.7131561040878296
# Epoch: 13 || example: 200
# 0
# 0
# 0.6814854145050049
# Epoch: 14 || example: 0
# 0
# 0
# 0.6837931871414185
# Epoch: 14 || example: 1
# 0
# 0
# 0.6809703707695007
# Epoch: 14 || example: 2
# 0
# 0
# 0.6735833883285522
# Epoch: 14 || example: 3
# 0
# 0
# 0.6622239351272583
# Epoch: 14 || example: 4
# 1
# 0
# 0.7409910559654236
# Epoch: 14 || example: 5
# 1
# 0
# 0.749995768070221
# Epoch: 14 || example: 6
# 0
# 0
# 0.6370601654052734
# Epoch: 14 || example: 7
# 0
# 0
# 0.6305792927742004
# Epoch: 14 || example: 8
# 1
# 0
# 0.7715443968772888
# Epoch: 14 || example: 9
# 1
# 0
# 0.7763113975524902
# Epoch: 14 || example: 10
# 0
# 0
# 0.6176769733428955
# Epoch: 14 || example: 11
# 1
# 0
# 0.7783803939819336
# Epoch: 14 || example: 12
# 1
# 0
# 0.775776743888855
# Epoch: 14 || example: 13
# 0
# 0
# 0.6238208413124084
# Epoch: 14 || example: 14
# 0
# 0
# 0.6258352398872375
# Epoch: 14 || example: 15
# 1
# 0
# 0.7682119011878967
# Epoch: 14 || example: 16
# 0
# 0
# 0.6260489225387573
# Epoch: 14 || example: 17
# 1
# 0
# 0.7672308683395386
# Epoch: 14 || example: 18
# 1
# 0
# 0.7634409666061401
# Epoch: 14 || example: 19
# 1
# 0
# 0.7543699741363525
# Epoch: 14 || example: 20
# 1
# 0
# 0.7407110929489136
# Epoch: 14 || example: 21
# 0
# 0
# 0.6640079021453857
# Epoch: 14 || example: 22
# 1
# 0
# 0.712543785572052
# Epoch: 14 || example: 23
# 0
# 0
# 0.6883706450462341
# Epoch: 14 || example: 24
# 0
# 1
# 0.6963698863983154
# Epoch: 14 || example: 25
# 0
# 1
# 0.6985683441162109
# Epoch: 14 || example: 26
# 0
# 1
# 0.6954995393753052
# Epoch: 14 || example: 27
# 1
# 0
# 0.6985753178596497
# Epoch: 14 || example: 28
# 1
# 0
# 0.700547456741333
# Epoch: 14 || example: 29
# 0
# 0
# 0.6890556812286377
# Epoch: 14 || example: 30
# 1
# 0
# 0.6992995142936707
# Epoch: 14 || example: 31
# 0
# 0
# 0.6902183294296265
# Epoch: 14 || example: 32
# 1
# 0
# 0.6981979608535767
# Epoch: 14 || example: 33
# 0
# 0
# 0.6912416219711304
# Epoch: 14 || example: 34
# 1
# 0
# 0.6972357630729675
# Epoch: 14 || example: 35
# 0
# 0
# 0.692132294178009
# Epoch: 14 || example: 36
# 0
# 0
# 0.6899005174636841
# Epoch: 14 || example: 37
# 0
# 0
# 0.6829510927200317
# Epoch: 14 || example: 38
# 0
# 0
# 0.6718838214874268
# Epoch: 14 || example: 39
# 0
# 0
# 0.6573054194450378
# Epoch: 14 || example: 40
# 0
# 0
# 0.6398121118545532
# Epoch: 14 || example: 41
# 0
# 0
# 0.6199761629104614
# Epoch: 14 || example: 42
# 1
# 0
# 0.7978991270065308
# Epoch: 14 || example: 43
# 1
# 0
# 0.8154516220092773
# Epoch: 14 || example: 44
# 1
# 0
# 0.8251802921295166
# Epoch: 14 || example: 45
# 1
# 0
# 0.8276586532592773
# Epoch: 14 || example: 46
# 0
# 0
# 0.5777963399887085
# Epoch: 14 || example: 47
# 0
# 0
# 0.5768252015113831
# Epoch: 14 || example: 48
# 1
# 0
# 0.8308606147766113
# Epoch: 14 || example: 49
# 1
# 0
# 0.8299560546875
# Epoch: 14 || example: 50
# 1
# 0
# 0.8228018879890442
# Epoch: 14 || example: 51
# 1
# 0
# 0.810154378414154
# Epoch: 14 || example: 52
# 1
# 0
# 0.7927863001823425
# Epoch: 14 || example: 53
# 1
# 0
# 0.7714636921882629
# Epoch: 14 || example: 54
# 0
# 0
# 0.6421108245849609
# Epoch: 14 || example: 55
# 1
# 0
# 0.7302005887031555
# Epoch: 14 || example: 56
# 1
# 0
# 0.7100816965103149
# Epoch: 14 || example: 57
# 1
# 1
# 0.6872361898422241
# Epoch: 14 || example: 58
# 0
# 1
# 0.7249871492385864
# Epoch: 14 || example: 59
# 1
# 1
# 0.6452804803848267
# Epoch: 14 || example: 60
# 0
# 1
# 0.765353798866272
# Epoch: 14 || example: 61
# 1
# 1
# 0.6135329604148865
# Epoch: 14 || example: 62
# 1
# 1
# 0.5984969735145569
# Epoch: 14 || example: 63
# 0
# 1
# 0.8192046880722046
# Epoch: 14 || example: 64
# 0
# 1
# 0.8325390815734863
# Epoch: 14 || example: 65
# 0
# 1
# 0.8382291793823242
# Epoch: 14 || example: 66
# 0
# 1
# 0.8369202613830566
# Epoch: 14 || example: 67
# 1
# 1
# 0.5733019709587097
# Epoch: 14 || example: 68
# 0
# 1
# 0.8274507522583008
# Epoch: 14 || example: 69
# 1
# 1
# 0.5810271501541138
# Epoch: 14 || example: 70
# 1
# 1
# 0.5828046202659607
# Epoch: 14 || example: 71
# 0
# 1
# 0.820103645324707
# Epoch: 14 || example: 72
# 0
# 1
# 0.8164681196212769
# Epoch: 14 || example: 73
# 0
# 1
# 0.807009220123291
# Epoch: 14 || example: 74
# 1
# 1
# 0.6027956604957581
# Epoch: 14 || example: 75
# 0
# 1
# 0.7844638824462891
# Epoch: 14 || example: 76
# 0
# 1
# 0.7714345455169678
# Epoch: 14 || example: 77
# 0
# 1
# 0.7541226744651794
# Epoch: 14 || example: 78
# 0
# 1
# 0.7332481145858765
# Epoch: 14 || example: 79
# 1
# 1
# 0.6770530343055725
# Epoch: 14 || example: 80
# 0
# 1
# 0.6935001611709595
# Epoch: 14 || example: 81
# 1
# 0
# 0.7122609615325928
# Epoch: 14 || example: 82
# 1
# 0
# 0.72483229637146
# Epoch: 14 || example: 83
# 1
# 0
# 0.7309147119522095
# Epoch: 14 || example: 84
# 1
# 0
# 0.7310268878936768
# Epoch: 14 || example: 85
# 0
# 0
# 0.6615623831748962
# Epoch: 14 || example: 86
# 1
# 0
# 0.7260304093360901
# Epoch: 14 || example: 87
# 0
# 0
# 0.6660914421081543
# Epoch: 14 || example: 88
# 1
# 0
# 0.7213950753211975
# Epoch: 14 || example: 89
# 1
# 0
# 0.7165197134017944
# Epoch: 14 || example: 90
# 1
# 0
# 0.7069523930549622
# Epoch: 14 || example: 91
# 1
# 0
# 0.6933350563049316
# Epoch: 14 || example: 92
# 0
# 1
# 0.7102755308151245
# Epoch: 14 || example: 93
# 0
# 1
# 0.7208752632141113
# Epoch: 14 || example: 94
# 1
# 1
# 0.6620945930480957
# Epoch: 14 || example: 95
# 0
# 1
# 0.7341228127479553
# Epoch: 14 || example: 96
# 0
# 1
# 0.7367849349975586
# Epoch: 14 || example: 97
# 0
# 1
# 0.7337518930435181
# Epoch: 14 || example: 98
# 0
# 1
# 0.7256507277488708
# Epoch: 14 || example: 99
# 1
# 1
# 0.6735495924949646
# Epoch: 14 || example: 100
# 0
# 1
# 0.706957221031189
# Epoch: 14 || example: 101
# 1
# 1
# 0.6899746060371399
# Epoch: 14 || example: 102
# 0
# 0
# 0.691825270652771
# Epoch: 14 || example: 103
# 1
# 0
# 0.7035674452781677
# Epoch: 14 || example: 104
# 0
# 0
# 0.6797836422920227
# Epoch: 14 || example: 105
# 1
# 0
# 0.714536726474762
# Epoch: 14 || example: 106
# 0
# 0
# 0.6704115867614746
# Epoch: 14 || example: 107
# 1
# 0
# 0.7231194972991943
# Epoch: 14 || example: 108
# 1
# 0
# 0.723876416683197
# Epoch: 14 || example: 109
# 1
# 0
# 0.7192606329917908
# Epoch: 14 || example: 110
# 1
# 0
# 0.709896445274353
# Epoch: 14 || example: 111
# 1
# 0
# 0.6964280009269714
# Epoch: 14 || example: 112
# 1
# 1
# 0.6794984340667725
# Epoch: 14 || example: 113
# 0
# 1
# 0.7277160882949829
# Epoch: 14 || example: 114
# 1
# 1
# 0.6472086906433105
# Epoch: 14 || example: 115
# 1
# 1
# 0.6316079497337341
# Epoch: 14 || example: 116
# 1
# 1
# 0.6134941577911377
# Epoch: 14 || example: 117
# 0
# 1
# 0.8039559721946716
# Epoch: 14 || example: 118
# 1
# 1
# 0.5805847644805908
# Epoch: 14 || example: 119
# 1
# 1
# 0.5654117465019226
# Epoch: 14 || example: 120
# 0
# 1
# 0.8625123500823975
# Epoch: 14 || example: 121
# 0
# 1
# 0.8766824007034302
# Epoch: 14 || example: 122
# 0
# 1
# 0.8826960325241089
# Epoch: 14 || example: 123
# 0
# 1
# 0.8812448978424072
# Epoch: 14 || example: 124
# 1
# 1
# 0.5406907796859741
# Epoch: 14 || example: 125
# 0
# 1
# 0.8706601858139038
# Epoch: 14 || example: 126
# 0
# 1
# 0.8617351055145264
# Epoch: 14 || example: 127
# 0
# 1
# 0.847135603427887
# Epoch: 14 || example: 128
# 0
# 1
# 0.8276824951171875
# Epoch: 14 || example: 129
# 0
# 1
# 0.8041855096817017
# Epoch: 14 || example: 130
# 0
# 1
# 0.7774258852005005
# Epoch: 14 || example: 131
# 0
# 1
# 0.7481435537338257
# Epoch: 14 || example: 132
# 1
# 1
# 0.6698258519172668
# Epoch: 14 || example: 133
# 0
# 1
# 0.6946637034416199
# Epoch: 14 || example: 134
# 0
# 0
# 0.6700519919395447
# Epoch: 14 || example: 135
# 1
# 0
# 0.7450757622718811
# Epoch: 14 || example: 136
# 1
# 0
# 0.7655354142189026
# Epoch: 14 || example: 137
# 1
# 0
# 0.7784650921821594
# Epoch: 14 || example: 138
# 1
# 0
# 0.7843297719955444
# Epoch: 14 || example: 139
# 0
# 0
# 0.6101077795028687
# Epoch: 14 || example: 140
# 0
# 0
# 0.6064118146896362
# Epoch: 14 || example: 141
# 1
# 0
# 0.7970989942550659
# Epoch: 14 || example: 142
# 0
# 0
# 0.5972954034805298
# Epoch: 14 || example: 143
# 1
# 0
# 0.8060040473937988
# Epoch: 14 || example: 144
# 0
# 0
# 0.5917100310325623
# Epoch: 14 || example: 145
# 0
# 0
# 0.5876992344856262
# Epoch: 14 || example: 146
# 0
# 0
# 0.5801841616630554
# Epoch: 14 || example: 147
# 0
# 0
# 0.5696486234664917
# Epoch: 14 || example: 148
# 1
# 0
# 0.8513705730438232
# Epoch: 14 || example: 149
# 0
# 0
# 0.5498286485671997
# Epoch: 14 || example: 150
# 1
# 0
# 0.8736850619316101
# Epoch: 14 || example: 151
# 1
# 0
# 0.8788310885429382
# Epoch: 14 || example: 152
# 1
# 0
# 0.8766345381736755
# Epoch: 14 || example: 153
# 0
# 0
# 0.5444598197937012
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 83
#      81 for epoch in range(100):
#      82     for id, (x, y) in enumerate(dataset):
# ---> 83         y_hat = model(x)
#      84         loss = loss_calculator(y_hat, y)
#      85         print(f"Epoch: {epoch} || example: {id}")
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[13], line 64, in RNN.forward(self, frames)
#      62 last_s = None
#      63 for frame in frames:
# ---> 64     feature_vector = self.get_feature(frame)
#      65     last_s = self.cell(feature_vector, last_s)
#      68 last_s = f.relu(self.fc1(last_s))
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# Cell In[13], line 24, in GetFeature.forward(self, x)
#      21 def forward(self, x):
#      23     x = f.relu(self.conv1(x))
# ---> 24     x = self.maxpool1(x)
#      25     x = f.relu(self.conv2(x))
#      26     x = self.maxpool2(x)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/modules/pooling.py:213, in MaxPool2d.forward(self, input)
#     212 def forward(self, input: Tensor):
# --> 213     return F.max_pool2d(
#     214         input,
#     215         self.kernel_size,
#     216         self.stride,
#     217         self.padding,
#     218         self.dilation,
#     219         ceil_mode=self.ceil_mode,
#     220         return_indices=self.return_indices,
#     221     )
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/_jit_internal.py:624, in boolean_dispatch.<locals>.fn(*args, **kwargs)
#     622     return if_true(*args, **kwargs)
#     623 else:
# --> 624     return if_false(*args, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/nn/functional.py:830, in _max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode, return_indices)
#     828 if stride is None:
#     829     stride = torch.jit.annotate(List[int], [])
# --> 830 return torch.max_pool2d(input, kernel_size, stride, padding, dilation, ceil_mode)
#
# KeyboardInterrupt:

# %% [markdown]
# # LSTM

# %%
class LSTMCell(nn.Module):
    def __init__(self):
        super().__init__()
        self.sigmoid1 = nn.Linear(INPUTSIZE + 128, 128)
        
        self.sigmoid2 = nn.Linear(INPUTSIZE + 128, 128)
        self.tanh1 = nn.Linear(INPUTSIZE + 128, 128)
        
        self.sigmoid3 = nn.Linear(INPUTSIZE + 128, 128)
        self.tanh2 = nn.Linear(128, 128)
        
        

    def forward(self, x, s = None, c = None):
        if s == None:
            s = torch.zeros(128)
        if c == None:
            c = torch.zeros(128)
        
        #sigmoid 1
        # để bỏ bớt đi mấy cái feature không quan trọng trong c
        # dùng sigmoid để bỏ đi mấy cái feature không quan trọng, vì sigmoid chạy từ [0,1] (bỏ hoàn toàn, giữ hoàn toàn)
        xs = torch.cat((x,s))
        sig1_xs = f.sigmoid(self.sigmoid1(xs))
        c = c * sig1_xs
        
        #sigmoid 2
        # thêm các feature quan trọng vào c, hàm tanh được dùng để tạo sự tích cực hay tiêu cực cho feature
        # dùng sigmoid và tanh để tạo sự phức tạp cho mạng
        sig2_xs = f.sigmoid(self.sigmoid2(xs))
        tanh1_xs = f.tanh(self.tanh1(xs))
        sig2tanh1_xs = sig2_xs * tanh1_xs
        c = c + sig2tanh1_xs
        
        #sigmoid 3
        # kết hợp c vào việc tính s ở output
        sig3_xs = f.sigmoid(self.sigmoid3(xs))
        tanh2_xs = f.tanh(self.tanh2(c))
        
        s = sig3_xs * tanh2_xs
        

        return s, c

class LTSM(nn.Module):
    def __init__(self):
        super().__init__()
        self.cell = LSTMCell()
        self.get_feature = GetFeature()

        self.fc1 = nn.Linear(128, 64)
        self.fc2 = nn.Linear(64, 2)


    def forward(self, frames):
        last_s = None
        last_c = None
        for frame in frames:
            feature_vector = self.get_feature(frame)
            last_s, last_c = self.cell(feature_vector, last_s, last_c)

        last_s = f.relu(self.fc1(last_s))
        last_s = self.fc2(last_s)

        return last_s

model = LTSM()

import torch.optim as optim

optimizer = optim.SGD(model.parameters(), lr = 0.01, momentum = 0.9)

loss_calculator = nn.CrossEntropyLoss()

for epoch in range(100):
    for id, (x, y) in enumerate(dataset):
        y_hat = model(x)
        loss = loss_calculator(y_hat, y)
        print(f"Epoch: {epoch} || example: {id}")
        print(y.numpy())
        print(torch.argmax(y_hat).numpy())
        print(loss.item())

        optimizer.zero_grad()

        loss.backward()

        optimizer.step()
# Out:
# Epoch: 0 || example: 0
# 1
# 0
# 0.718099057674408
# Epoch: 0 || example: 1
# 0
# 1
# 0.7839987874031067
# Epoch: 0 || example: 2
# 0
# 1
# 0.7300007939338684
# Epoch: 0 || example: 3
# 1
# 1
# 0.6871210336685181
# Epoch: 0 || example: 4
# 1
# 1
# 0.6790741682052612
# Epoch: 0 || example: 5
# 1
# 1
# 0.6491162180900574
# Epoch: 0 || example: 6
# 0
# 1
# 0.7632565498352051
# Epoch: 0 || example: 7
# 0
# 1
# 0.7593437433242798
# Epoch: 0 || example: 8
# 0
# 1
# 0.7502493262290955
# Epoch: 0 || example: 9
# 0
# 1
# 0.7332251667976379
# Epoch: 0 || example: 10
# 1
# 1
# 0.6738114356994629
# Epoch: 0 || example: 11
# 0
# 1
# 0.697658360004425
# Epoch: 0 || example: 12
# 0
# 0
# 0.6778993606567383
# Epoch: 0 || example: 13
# 1
# 0
# 0.730548620223999
# Epoch: 0 || example: 14
# 1
# 0
# 0.7411055564880371
# Epoch: 0 || example: 15
# 1
# 0
# 0.7481496930122375
# Epoch: 0 || example: 16
# 1
# 0
# 0.7317287921905518
# Epoch: 0 || example: 17
# 1
# 0
# 0.7166278958320618
# Epoch: 0 || example: 18
# 0
# 1
# 0.6992001533508301
# Epoch: 0 || example: 19
# 1
# 1
# 0.6727598309516907
# Epoch: 0 || example: 20
# 0
# 1
# 0.7352619767189026
# Epoch: 0 || example: 21
# 1
# 1
# 0.6444532871246338
# Epoch: 0 || example: 22
# 0
# 1
# 0.761982798576355
# Epoch: 0 || example: 23
# 1
# 1
# 0.6240255236625671
# Epoch: 0 || example: 24
# 0
# 1
# 0.7816439270973206
# Epoch: 0 || example: 25
# 1
# 1
# 0.6109185814857483
# Epoch: 0 || example: 26
# 1
# 1
# 0.6017493009567261
# Epoch: 0 || example: 27
# 0
# 1
# 0.8105445504188538
# Epoch: 0 || example: 28
# 1
# 1
# 0.5847331285476685
# Epoch: 0 || example: 29
# 0
# 1
# 0.8283278346061707
# Epoch: 0 || example: 30
# 1
# 1
# 0.574351966381073
# Epoch: 0 || example: 31
# 0
# 1
# 0.8374269604682922
# Epoch: 0 || example: 32
# 0
# 1
# 0.8329188823699951
# Epoch: 0 || example: 33
# 1
# 1
# 0.5835720896720886
# Epoch: 0 || example: 34
# 1
# 1
# 0.5876501798629761
# Epoch: 0 || example: 35
# 1
# 1
# 0.5836063623428345
# Epoch: 0 || example: 36
# 1
# 1
# 0.5723655819892883
# Epoch: 0 || example: 37
# 0
# 1
# 0.8536382913589478
# Epoch: 0 || example: 38
# 1
# 1
# 0.549214243888855
# Epoch: 0 || example: 39
# 1
# 1
# 0.5369192361831665
# Epoch: 0 || example: 40
# 0
# 1
# 0.9039707779884338
# Epoch: 0 || example: 41
# 1
# 1
# 0.5136014223098755
# Epoch: 0 || example: 42
# 0
# 1
# 0.9296709299087524
# Epoch: 0 || example: 43
# 0
# 1
# 0.9296984672546387
# Epoch: 0 || example: 44
# 1
# 1
# 0.5121002793312073
# Epoch: 0 || example: 45
# 1
# 1
# 0.5140905976295471
# Epoch: 0 || example: 46
# 0
# 1
# 0.9196423888206482
# Epoch: 0 || example: 47
# 1
# 1
# 0.5146551132202148
# Epoch: 0 || example: 48
# 1
# 1
# 0.5134796500205994
# Epoch: 0 || example: 49
# 1
# 1
# 0.5058633089065552
# Epoch: 0 || example: 50
# 0
# 1
# 0.9443556070327759
# Epoch: 0 || example: 51
# 0
# 1
# 0.9471444487571716
# Epoch: 0 || example: 52
# 1
# 1
# 0.4993221163749695
# Epoch: 0 || example: 53
# 1
# 1
# 0.5005792379379272
# Epoch: 0 || example: 54
# 1
# 1
# 0.49533408880233765
# Epoch: 0 || example: 55
# 0
# 1
# 0.9574275016784668
# Epoch: 0 || example: 56
# 0
# 1
# 0.9570727348327637
# Epoch: 0 || example: 57
# 1
# 1
# 0.49477219581604004
# Epoch: 0 || example: 58
# 0
# 1
# 0.9362976551055908
# Epoch: 0 || example: 59
# 0
# 1
# 0.9175580739974976
# Epoch: 0 || example: 60
# 0
# 1
# 0.8876971006393433
# Epoch: 0 || example: 61
# 1
# 1
# 0.5575679540634155
# Epoch: 0 || example: 62
# 1
# 1
# 0.575516402721405
# Epoch: 0 || example: 63
# 0
# 1
# 0.8141720294952393
# Epoch: 0 || example: 64
# 1
# 1
# 0.600980818271637
# Epoch: 0 || example: 65
# 0
# 1
# 0.7850176095962524
# Epoch: 0 || example: 66
# 0
# 1
# 0.7677638530731201
# Epoch: 0 || example: 67
# 0
# 1
# 0.7446034550666809
# Epoch: 0 || example: 68
# 1
# 1
# 0.6696214079856873
# Epoch: 0 || example: 69
# 1
# 1
# 0.6858088374137878
# Epoch: 0 || example: 70
# 0
# 0
# 0.6927474141120911
# Epoch: 0 || example: 71
# 0
# 0
# 0.6791818141937256
# Epoch: 0 || example: 72
# 0
# 0
# 0.6608267426490784
# Epoch: 0 || example: 73
# 0
# 0
# 0.638322114944458
# Epoch: 0 || example: 74
# 0
# 0
# 0.6122764348983765
# Epoch: 0 || example: 75
# 0
# 0
# 0.5821826457977295
# Epoch: 0 || example: 76
# 1
# 0
# 0.8619388341903687
# Epoch: 0 || example: 77
# 0
# 0
# 0.5287210941314697
# Epoch: 0 || example: 78
# 1
# 0
# 0.9259048700332642
# Epoch: 0 || example: 79
# 1
# 0
# 0.9437152147293091
# Epoch: 0 || example: 80
# 0
# 0
# 0.49271225929260254
# Epoch: 0 || example: 81
# 1
# 0
# 0.9542772769927979
# Epoch: 0 || example: 82
# 1
# 0
# 0.9478203058242798
# Epoch: 0 || example: 83
# 1
# 0
# 0.9296813607215881
# Epoch: 0 || example: 84
# 1
# 0
# 0.9040879011154175
# Epoch: 0 || example: 85
# 0
# 0
# 0.5415501594543457
# Epoch: 0 || example: 86
# 0
# 0
# 0.5563434362411499
# Epoch: 0 || example: 87
# 1
# 0
# 0.8409940600395203
# Epoch: 0 || example: 88
# 1
# 0
# 0.8233427405357361
# Epoch: 0 || example: 89
# 0
# 0
# 0.5963011980056763
# Epoch: 0 || example: 90
# 1
# 0
# 0.7869151830673218
# Epoch: 0 || example: 91
# 1
# 0
# 0.7681843042373657
# Epoch: 0 || example: 92
# 0
# 0
# 0.6433297991752625
# Epoch: 0 || example: 93
# 1
# 0
# 0.7318601012229919
# Epoch: 0 || example: 94
# 0
# 0
# 0.6726212501525879
# Epoch: 0 || example: 95
# 0
# 0
# 0.682341992855072
# Epoch: 0 || example: 96
# 0
# 0
# 0.685626745223999
# Epoch: 0 || example: 97
# 0
# 0
# 0.68290776014328
# Epoch: 0 || example: 98
# 0
# 0
# 0.6750438809394836
# Epoch: 0 || example: 99
# 0
# 0
# 0.6627442836761475
# Epoch: 0 || example: 100
# 1
# 0
# 0.7418688535690308
# Epoch: 0 || example: 101
# 0
# 0
# 0.637977659702301
# Epoch: 0 || example: 102
# 0
# 0
# 0.625350296497345
# Epoch: 0 || example: 103
# 0
# 0
# 0.6094538569450378
# Epoch: 0 || example: 104
# 1
# 0
# 0.8069958686828613
# Epoch: 0 || example: 105
# 0
# 0
# 0.5801512002944946
# Epoch: 0 || example: 106
# 1
# 0
# 0.8383960127830505
# Epoch: 0 || example: 107
# 1
# 0
# 0.8474656343460083
# Epoch: 0 || example: 108
# 0
# 0
# 0.5587942004203796
# Epoch: 0 || example: 109
# 1
# 0
# 0.8546708226203918
# Epoch: 0 || example: 110
# 1
# 0
# 0.8530029058456421
# Epoch: 0 || example: 111
# 1
# 0
# 0.8442617654800415
# Epoch: 0 || example: 112
# 0
# 0
# 0.5732380747795105
# Epoch: 0 || example: 113
# 0
# 0
# 0.5793620944023132
# Epoch: 0 || example: 114
# 0
# 0
# 0.580691397190094
# Epoch: 0 || example: 115
# 0
# 0
# 0.57769376039505
# Epoch: 0 || example: 116
# 0
# 0
# 0.5708727240562439
# Epoch: 0 || example: 117
# 1
# 0
# 0.8458243608474731
# Epoch: 0 || example: 118
# 0
# 0
# 0.5569620132446289
# Epoch: 0 || example: 119
# 1
# 0
# 0.8613710403442383
# Epoch: 0 || example: 120
# 0
# 0
# 0.5481770038604736
# Epoch: 0 || example: 121
# 1
# 0
# 0.8699678182601929
# Epoch: 0 || example: 122
# 1
# 0
# 0.8682305216789246
# Epoch: 0 || example: 123
# 1
# 0
# 0.8595036268234253
# Epoch: 0 || example: 124
# 1
# 0
# 0.8448354005813599
# Epoch: 0 || example: 125
# 0
# 0
# 0.5767170190811157
# Epoch: 0 || example: 126
# 1
# 0
# 0.8125705718994141
# Epoch: 0 || example: 127
# 0
# 0
# 0.6006133556365967
# Epoch: 0 || example: 128
# 1
# 0
# 0.784850001335144
# Epoch: 0 || example: 129
# 1
# 0
# 0.7695995569229126
# Epoch: 0 || example: 130
# 1
# 0
# 0.7501762509346008
# Epoch: 0 || example: 131
# 1
# 0
# 0.7274438738822937
# Epoch: 0 || example: 132
# 0
# 0
# 0.684295117855072
# Epoch: 0 || example: 133
# 0
# 1
# 0.7014880180358887
# Epoch: 0 || example: 134
# 0
# 1
# 0.7119064927101135
# Epoch: 0 || example: 135
# 0
# 1
# 0.7159186601638794
# Epoch: 0 || example: 136
# 0
# 1
# 0.714402437210083
# Epoch: 0 || example: 137
# 1
# 1
# 0.6788418889045715
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 81
#      77 print(loss.item())
#      79 optimizer.zero_grad()
# ---> 81 loss.backward()
#      83 optimizer.step()
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/autograd/graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# # Peephole Architecture
# Nối thêm vector c vào xs trước các hàm sigmoid để tăng tính ảnh hưởng của c lên kết quả

# %%
class LSTMCell(nn.Module):
    def __init__(self):
        super().__init__()
        self.sigmoid1 = nn.Linear(INPUTSIZE + 128 + 128, 128)
        
        self.sigmoid2 = nn.Linear(INPUTSIZE + 128 + 128, 128)
        self.tanh1 = nn.Linear(INPUTSIZE + 128, 128)
        
        self.sigmoid3 = nn.Linear(INPUTSIZE + 128 + 128, 128)
        self.tanh2 = nn.Linear(128, 128)
        
        

    def forward(self, x, s = None, c = None):
        if s == None:
            s = torch.zeros(128)
        if c == None:
            c = torch.zeros(128)
        
        xs = torch.cat((x,s))
        xsc = torch.cat((xs, c))
        sig1_xs = f.sigmoid(self.sigmoid1(xsc))
        c = c * sig1_xs
        
        sig2_xs = f.sigmoid(self.sigmoid2(xsc))
        tanh1_xs = f.tanh(self.tanh1(xs))
        sig2tanh1_xs = sig2_xs * tanh1_xs
        c = c + sig2tanh1_xs
        
        sig3_xs = f.sigmoid(self.sigmoid3(torch.cat((xs, c))))
        tanh2_xs = f.tanh(self.tanh2(c))
        
        s = sig3_xs * tanh2_xs
        

        return s, c

class LTSM(nn.Module):
    def __init__(self):
        super().__init__()
        self.cell = LSTMCell()
        self.get_feature = GetFeature()

        self.fc1 = nn.Linear(128, 64)
        self.fc2 = nn.Linear(64, 2)


    def forward(self, frames):
        last_s = None
        last_c = None
        for frame in frames:
            feature_vector = self.get_feature(frame)
            last_s, last_c = self.cell(feature_vector, last_s, last_c)

        last_s = f.relu(self.fc1(last_s))
        last_s = self.fc2(last_s)

        return last_s

model = LTSM()

import torch.optim as optim

optimizer = optim.SGD(model.parameters(), lr = 0.01, momentum = 0.9)

loss_calculator = nn.CrossEntropyLoss()

for epoch in range(100):
    for id, (x, y) in enumerate(dataset):
        y_hat = model(x)
        loss = loss_calculator(y_hat, y)
        print(f"Epoch: {epoch} || example: {id}")
        print(y.numpy())
        print(torch.argmax(y_hat).numpy())
        print(loss.item())

        optimizer.zero_grad()

        loss.backward()

        optimizer.step()
# Out:
# Epoch: 0 || example: 0
# 1
# 0
# 0.7019950747489929
# Epoch: 0 || example: 1
# 0
# 1
# 0.7731455564498901
# Epoch: 0 || example: 2
# 0
# 1
# 0.724738359451294
# Epoch: 0 || example: 3
# 1
# 0
# 0.6981870532035828
# Epoch: 0 || example: 4
# 1
# 1
# 0.6906003952026367
# Epoch: 0 || example: 5
# 1
# 1
# 0.6657988429069519
# Epoch: 0 || example: 6
# 0
# 1
# 0.7439027428627014
# Epoch: 0 || example: 7
# 0
# 1
# 0.7489844560623169
# Epoch: 0 || example: 8
# 0
# 1
# 0.736472487449646
# Epoch: 0 || example: 9
# 0
# 1
# 0.7191302180290222
# Epoch: 0 || example: 10
# 1
# 1
# 0.6911607980728149
# Epoch: 0 || example: 11
# 0
# 0
# 0.6851422786712646
# Epoch: 0 || example: 12
# 0
# 0
# 0.6675310134887695
# Epoch: 0 || example: 13
# 1
# 0
# 0.7452117800712585
# Epoch: 0 || example: 14
# 1
# 0
# 0.7533529996871948
# Epoch: 0 || example: 15
# 1
# 0
# 0.7543352246284485
# Epoch: 0 || example: 16
# 1
# 0
# 0.7466088533401489
# Epoch: 0 || example: 17
# 1
# 0
# 0.7313017845153809
# Epoch: 0 || example: 18
# 0
# 0
# 0.6766842603683472
# Epoch: 0 || example: 19
# 1
# 0
# 0.6991128921508789
# Epoch: 0 || example: 20
# 0
# 1
# 0.7035485506057739
# Epoch: 0 || example: 21
# 1
# 1
# 0.6757835745811462
# Epoch: 0 || example: 22
# 0
# 1
# 0.7247325778007507
# Epoch: 0 || example: 23
# 1
# 1
# 0.65806645154953
# Epoch: 0 || example: 24
# 0
# 1
# 0.7411206960678101
# Epoch: 0 || example: 25
# 1
# 1
# 0.6451511383056641
# Epoch: 0 || example: 26
# 1
# 1
# 0.6362472176551819
# Epoch: 0 || example: 27
# 0
# 1
# 0.7692169547080994
# Epoch: 0 || example: 28
# 1
# 1
# 0.6173321604728699
# Epoch: 0 || example: 29
# 0
# 1
# 0.7881149649620056
# Epoch: 0 || example: 30
# 1
# 1
# 0.6036390066146851
# Epoch: 0 || example: 31
# 0
# 1
# 0.8008353114128113
# Epoch: 0 || example: 32
# 0
# 1
# 0.8003934621810913
# Epoch: 0 || example: 33
# 1
# 1
# 0.6035760045051575
# Epoch: 0 || example: 34
# 1
# 1
# 0.6049582958221436
# Epoch: 0 || example: 35
# 1
# 1
# 0.5996053218841553
# Epoch: 0 || example: 36
# 1
# 1
# 0.5879382491111755
# Epoch: 0 || example: 37
# 0
# 1
# 0.8298022150993347
# Epoch: 0 || example: 38
# 1
# 1
# 0.5657017827033997
# Epoch: 0 || example: 39
# 1
# 1
# 0.5541682243347168
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[25], line 79
#      75 print(loss.item())
#      77 optimizer.zero_grad()
# ---> 79 loss.backward()
#      81 optimizer.step()
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/_tensor.py:581, in Tensor.backward(self, gradient, retain_graph, create_graph, inputs)
#     571 if has_torch_function_unary(self):
#     572     return handle_torch_function(
#     573         Tensor.backward,
#     574         (self,),
#    (...)
#     579         inputs=inputs,
#     580     )
# --> 581 torch.autograd.backward(
#     582     self, gradient, retain_graph, create_graph, inputs=inputs
#     583 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/autograd/__init__.py:347, in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     342     retain_graph = create_graph
#     344 # The reason we repeat the same comment below is that
#     345 # some Python versions print out the first line of a multi-line function
#     346 # calls in the traceback and some print out the last line
# --> 347 _engine_run_backward(
#     348     tensors,
#     349     grad_tensors_,
#     350     retain_graph,
#     351     create_graph,
#     352     inputs,
#     353     allow_unreachable=True,
#     354     accumulate_grad=True,
#     355 )
#
# File /opt/anaconda3/lib/python3.12/site-packages/torch/autograd/graph.py:825, in _engine_run_backward(t_outputs, *args, **kwargs)
#     823     unregister_hooks = _register_logging_hooks_on_whole_graph(t_outputs)
#     824 try:
# --> 825     return Variable._execution_engine.run_backward(  # Calls into the C++ engine to run the backward pass
#     826         t_outputs, *args, **kwargs
#     827     )  # Calls into the C++ engine to run the backward pass
#     828 finally:
#     829     if attach_logging_hooks:
#
# KeyboardInterrupt:

# %% [markdown]
# # Gated Recurrent Unit
# Bỏ đi C, thay vào đó là cho cell có khả năng quyết định quên đi và thêm vào feature cần tiếp trực tiếp vào s
# Giảm độ phức tạp tính toán nhưng không chính xác bằng (chỉ có 3 hàm phi tuyến tính và fully connected)

# %%
class RNNCell(nn.Module):
    def __init__(self):
        super().__init__()
        
        self.sigmoid_forget = nn.Linear(INPUTSIZE + 128, 128)
        
        self.sigmoid_1  = nn.Linear(INPUTSIZE + 128, 128)
        self.tanh_1 = nn.Linear(INPUTSIZE + 128, 128)
        

    def forward(self, x, s = None):
        if s == None:
            s = torch.zeros(128)
        
        xs = torch.cat((x,s))
        
        xs_1 = torch.cat((f.sigmoid(self.sigmoid_1(xs)) * s, x))
        xs_1_tanh = f.tanh(self.tanh_1(xs_1))
        
        xs_sigmoid_forget = f.sigmoid(self.sigmoid_forget(xs))
        s = s * (1 - xs_sigmoid_forget)
        
        xs_2 = xs_1_tanh * xs_sigmoid_forget
        
        s = s * xs_2

        return s

class RNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.cell = RNNCell()
        self.get_feature = GetFeature()

        self.fc1 = nn.Linear(128, 64)
        self.fc2 = nn.Linear(64, 2)


    def forward(self, frames):
        last_s = None
        for frame in frames:
            feature_vector = self.get_feature(frame)
            last_s = self.cell(feature_vector, last_s)


        last_s = f.relu(self.fc1(last_s))
        last_s = self.fc2(last_s)

        return last_s

model = RNN()

import torch.optim as optim

optimizer = optim.SGD(model.parameters(), lr = 0.01, momentum = 0.9)

loss_calculator = nn.CrossEntropyLoss()

for epoch in range(100):
    for id, (x, y) in enumerate(dataset):
        y_hat = model(x)
        loss = loss_calculator(y_hat, y)
        print(f"Epoch: {epoch} || example: {id}")
        print(y.numpy())
        print(torch.argmax(y_hat).numpy())
        print(loss.item())

        optimizer.zero_grad()

        loss.backward()

        optimizer.step()
# Out:
# Epoch: 0 || example: 0
# 1
# 1
# 0.6230216026306152
# Epoch: 0 || example: 1
# 1
# 1
# 0.6175631284713745
# Epoch: 0 || example: 2
# 0
# 1
# 0.7870140671730042
# Epoch: 0 || example: 3
# 1
# 1
# 0.6045029759407043
# Epoch: 0 || example: 4
# 0
# 1
# 0.7998218536376953
# Epoch: 0 || example: 5
# 0
# 1
# 0.8006166815757751
# Epoch: 0 || example: 6
# 1
# 1
# 0.601833701133728
# Epoch: 0 || example: 7
# 0
# 1
# 0.7936781048774719
# Epoch: 0 || example: 8
# 0
# 1
# 0.78611159324646
# Epoch: 0 || example: 9
# 0
# 1
# 0.7718812823295593
# Epoch: 0 || example: 10
# 1
# 1
# 0.6375934481620789
# Epoch: 0 || example: 11
# 0
# 1
# 0.740597665309906
# Epoch: 0 || example: 12
# 1
# 1
# 0.6636122465133667
# Epoch: 0 || example: 13
# 0
# 1
# 0.7147839665412903
# Epoch: 0 || example: 14
# 1
# 1
# 0.68599534034729
# Epoch: 0 || example: 15
# 1
# 1
# 0.6924451589584351
# Epoch: 0 || example: 16
# 0
# 1
# 0.6944000720977783
# Epoch: 0 || example: 17
# 1
# 0
# 0.6977977156639099
# Epoch: 0 || example: 18
# 1
# 0
# 0.6966854333877563
# Epoch: 0 || example: 19
# 1
# 1
# 0.6892927885055542
# Epoch: 0 || example: 20
# 1
# 1
# 0.6764387488365173
# Epoch: 0 || example: 21
# 0
# 1
# 0.7285212874412537
# Epoch: 0 || example: 22
# 1
# 1
# 0.6498095989227295
# Epoch: 0 || example: 23
# 1
# 1
# 0.6359305381774902
# Epoch: 0 || example: 24
# 0
# 1
# 0.7742440700531006
# Epoch: 0 || example: 25
# 1
# 1
# 0.6086244583129883
# Epoch: 0 || example: 26
# 1
# 1
# 0.5949952602386475
# Epoch: 0 || example: 27
# 1
# 1
# 0.5779629349708557
# Epoch: 0 || example: 28
# 0
# 1
# 0.8491593599319458
# Epoch: 0 || example: 29
# 1
# 1
# 0.5469695925712585
# Epoch: 0 || example: 30
# 0
# 1
# 0.8843796253204346
# Epoch: 0 || example: 31
# 1
# 1
# 0.5260320901870728
# Epoch: 0 || example: 32
# 0
# 1
# 0.9086005091667175
# Epoch: 0 || example: 33
# 0
# 1
# 0.9130126237869263
# Epoch: 0 || example: 34
# 1
# 1
# 0.5163437724113464
# Epoch: 0 || example: 35
# 0
# 1
# 0.9096195101737976
# Epoch: 0 || example: 36
# 1
# 1
# 0.5203557014465332
# Epoch: 0 || example: 37
# 1
# 1
# 0.5208343863487244
# Epoch: 0 || example: 38
# 0
# 1
# 0.9068277478218079
# Epoch: 0 || example: 39
# 1
# 1
# 0.5198884010314941
# Epoch: 0 || example: 40
# 0
# 1
# 0.9052532911300659
# Epoch: 0 || example: 41
# 0
# 1
# 0.8986416459083557
# Epoch: 0 || example: 42
# 0
# 1
# 0.8840774297714233
# Epoch: 0 || example: 43
# 0
# 1
# 0.862690269947052
# Epoch: 0 || example: 44
# 0
# 1
# 0.8356271386146545
# Epoch: 0 || example: 45
# 1
# 1
# 0.5933539271354675
# Epoch: 0 || example: 46
# 1
# 1
# 0.6113523244857788
# Epoch: 0 || example: 47
# 0
# 1
# 0.7690140008926392
# Epoch: 0 || example: 48
# 0
# 1
# 0.7502552270889282
# Epoch: 0 || example: 49
# 0
# 1
# 0.7269061207771301
# Epoch: 0 || example: 50
# 0
# 1
# 0.6998896598815918
# Epoch: 0 || example: 51
# 1
# 0
# 0.7167592644691467
# Epoch: 0 || example: 52
# 0
# 0
# 0.6500532031059265
# Epoch: 0 || example: 53
# 1
# 0
# 0.7640460133552551
# Epoch: 0 || example: 54
# 0
# 0
# 0.612772524356842
# Epoch: 0 || example: 55
# 1
# 0
# 0.8018237352371216
# Epoch: 0 || example: 56
# 1
# 0
# 0.8136764168739319
# Epoch: 0 || example: 57
# 1
# 0
# 0.8167232275009155
# Epoch: 0 || example: 58
# 0
# 0
# 0.5871081352233887
# Epoch: 0 || example: 59
# 0
# 0
# 0.5857897400856018
# Epoch: 0 || example: 60
# 1
# 0
# 0.8210239410400391
# Epoch: 0 || example: 61
# 0
# 0
# 0.5804769992828369
# Epoch: 0 || example: 62
# 0
# 0
# 0.5763353705406189
