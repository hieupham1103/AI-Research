# %% [markdown]
# # RNN and LTSM

# %% [markdown]
# Model nhận biết hành động đánh hay không đánh

# %%
import os
import kagglehub

# Download latest version
dataset_path = kagglehub.dataset_download("naveenk903/movies-fight-detection-dataset") + "/Peliculas"

print("Path to dataset files:", dataset_path)
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.3)
# Path to dataset files: /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas

# %%
labels = ['noFights', 'fights']
labels2id = {'noFights': 0, 'fights': 1}

print(labels)

number_of_labels = 2
# Out:
# ['noFights', 'fights']

# %%
import torch
from torch import nn
import torch.nn.functional as f
from PIL import Image
from torchvision import models, transforms, datasets
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

INPUTSIZE = 224

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


def load_video_to_tensors(video_path):
    # Open the video file
    video = cv2.VideoCapture(video_path)

    frames = []

    while True:
        ret, frame = video.read()
        if not ret:
            break

        frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        frame = cv2.resize(frame, (INPUTSIZE, INPUTSIZE), interpolation=cv2.INTER_LINEAR)
        # plt.figure()
        # plt.imshow(frame)

        frame = torch.from_numpy(frame).float().permute(2,0,1)

        # print(frame.size())
        frames.append(frame)


    video.release()

    return frames

dataset = []

for label in labels:
    label_path = f"{dataset_path}/{label}"

    for video in os.listdir(label_path):
        video_path = f"{label_path}/{video}"
        print(video_path)
        x = load_video_to_tensors(video_path)
        y = torch.tensor(labels2id[label])
        # print(x, y)
        # break

        dataset.append((x,y))
# Out:
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/68.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/1.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/53.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/74.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/76.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/50.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/16.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/35.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/47.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/28.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/61.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/92.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/17.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/100.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/94.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/98.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/66.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/59.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/75.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/32.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/39.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/43 (1).mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/34.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/67 (1).mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/49.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/78.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/82.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/31.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/87.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/80.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/54.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/44.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/46.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/4 (1).mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/70.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/29.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/51.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/95.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/62.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/13.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/83.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/86.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/71avi.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/22.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/27.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/23.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/84.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/93.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/99.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/57.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/3.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/14.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/7.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/97.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/91.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/56.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/41 (1).mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/79.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/89.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/55.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/69.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/8.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/5.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/24.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/21.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/58.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/64.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/45.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/6.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/25.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/77.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/30.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/85.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/2.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/18.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/52.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/9.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/60.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/37.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/10.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/72.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/33 (1).mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/36.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/65.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/12 (1).mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/26 (1).mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/48.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/40.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/20 (1).mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/42 (1).mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/96.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/19.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/88.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/81.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/33.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/73.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/90.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/63.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/15.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/38.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/noFights/11.mpg
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi17.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi35.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi83.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi68.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi34.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi57.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi92.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi28.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi82.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi60.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi38.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi84.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi73.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi8.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi67.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi69.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi76.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi86.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi94.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi9.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi49.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi81.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi41.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi27.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi50.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi54.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi14.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi88.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi85.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi95.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi55.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi44.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi32.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi2.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi66.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi37.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi26.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi71.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi3.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi1.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi12.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi96.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi93.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi21.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi90.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi99.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi5.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi33.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi43.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi29.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi13.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi42.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi7.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi40.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi91.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi64.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi65.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi4.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi100.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi11.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi58.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi19.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi72.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi46.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi98.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi31.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi18.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi97.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi15.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi23.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi45.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi6.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi56.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi89.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi78.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi80.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi74avi.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi20.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi62.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi36.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi61.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi75.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi77.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi22.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi63.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi52.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi87.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi53.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi30.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi25.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi70.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi48.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi47.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi24.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi16.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi10.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi59.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi39.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi51.avi
# /root/.cache/kagglehub/datasets/naveenk903/movies-fight-detection-dataset/versions/1/Peliculas/fights/newfi79.avi

# %%
import random

random.shuffle(dataset)

# %%
class GetFeature(nn.Module):
    def __init__(self):
        super().__init__()
        input_size  = INPUTSIZE

        self.conv1 = nn.Conv2d(3, 64, kernel_size = 3, stride = 1, padding = 1)
        self.maxpool1 = nn.MaxPool2d(2,2)
        input_size //= 2
        self.conv2 = nn.Conv2d(64, 128, kernel_size = 3, stride = 1, padding = 1)
        self.maxpool2 = nn.MaxPool2d(2,2)
        input_size //= 2
        self.conv3 = nn.Conv2d(128, 256, kernel_size = 3, stride = 1, padding = 1)
        self.maxpool3 = nn.MaxPool2d(2,2)
        input_size //= 2
        self.conv4 = nn.Conv2d(256, 512, kernel_size = 3, stride = 1, padding = 1)
        self.maxpool4 = nn.MaxPool2d(2,2)
        input_size //= 2

        self.fc1 = nn.Linear(input_size * input_size * 512, INPUTSIZE)

    def forward(self, x):

        x = f.relu(self.conv1(x))
        x = self.maxpool1(x)
        x = f.relu(self.conv2(x))
        x = self.maxpool2(x)
        x = f.relu(self.conv3(x))
        x = self.maxpool3(x)
        x = f.relu(self.conv4(x))
        x = self.maxpool4(x)

        x = torch.flatten(x)

        x = f.tanh(self.fc1(x))

        return x

class RNNCell(nn.Module):
    def __init__(self):
        super().__init__()
        self.Wx = nn.Linear(INPUTSIZE, 128)
        self.Ws = nn.Linear(128, 128)

    def forward(self, x, s = None):
        z = self.Wx(x)
        if not s == None:
            z = z + self.Ws(s)

        return f.tanh(z)

class RNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.cell = RNNCell()
        self.get_feature = GetFeature()

        self.fc1 = nn.Linear(128, 64)
        self.fc2 = nn.Linear(64, 2)


    def forward(self, frames):
        last_s = None
        for frame in frames:
            feature_vector = self.get_feature(frame)
            last_s = self.cell(feature_vector, last_s)


        last_s = f.relu(self.fc1(last_s))
        last_s = self.fc2(last_s)

        return last_s

model = RNN()

import torch.optim as optim

optimizer = optim.SGD(model.parameters(), lr = 0.01, momentum = 0.9)

loss_calculator = nn.CrossEntropyLoss()

for epoch in range(100):
    for id, (x, y) in enumerate(dataset):
        y_hat = model(x)
        loss = loss_calculator(y_hat, y)
        print(f"Epoch: {epoch} || example: {id}")
        print(y.numpy())
        print(torch.argmax(y_hat).numpy())
        print(loss.item())

        optimizer.zero_grad()

        loss.backward()

        optimizer.step()
# Out:
# Epoch: 0 || example: 0
# 0
# 0
# 0.6463481187820435
# Epoch: 0 || example: 1
# 0
# 0
# 0.39945659041404724
# Epoch: 0 || example: 2
# 1
# 0
# 1.3132573366165161
# Epoch: 0 || example: 3
# 0
# 0
# 0.3708879053592682
# Epoch: 0 || example: 4
# 0
# 0
# 0.35505905747413635
# Epoch: 0 || example: 5
# 1
# 0
# 1.2720891237258911
# Epoch: 0 || example: 6
# 0
# 0
# 0.3717461824417114
# Epoch: 0 || example: 7
# 0
# 0
# 0.38256293535232544
